# %% [markdown]
# <a href="https://colab.research.google.com/github/Yusuprozimemet/qpAdm_on_Colab/blob/main/qpAdm_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update
# !sudo apt-get install wget unzip
# !wget https://github.com/DReichLab/AdmixTools/archive/master.zip -O AdmixTools.zip
# !unzip AdmixTools.zip
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,546 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,299 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,187 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,411 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,728 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,034 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,127 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [2,655 kB]
# Get:21 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [48.1 kB]
# Fetched 23.3 MB in 5s (4,951 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 46 not upgraded.
# --2024-07-16 07:40:01--  https://github.com/DReichLab/AdmixTools/archive/master.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/DReichLab/AdmixTools/zip/refs/heads/master [following]
# --2024-07-16 07:40:01--  https://codeload.github.com/DReichLab/AdmixTools/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘AdmixTools.zip’
#
# AdmixTools.zip          [  <=>               ] 972.09K  2.15MB/s    in 0.4s
#
# 2024-07-16 07:40:02 (2.15 MB/s) - ‘AdmixTools.zip’ saved [995420]
#
# Archive:  AdmixTools.zip
# ed1d8579c550253ac748c7a81e625a7eec88fef0
#    creating: AdmixTools-master/
#   inflating: AdmixTools-master/.gitignore
#   inflating: AdmixTools-master/README
#   inflating: AdmixTools-master/README.3PopTest
#   inflating: AdmixTools-master/README.CONVERTF
#   inflating: AdmixTools-master/README.Dstatistics
#   inflating: AdmixTools-master/README.F4RatioTest
#   inflating: AdmixTools-master/README.INSTALL
#   inflating: AdmixTools-master/README.QPGRAPH
#   inflating: AdmixTools-master/README.QpWave
#   inflating: AdmixTools-master/README.REXPFIT
#   inflating: AdmixTools-master/README.ROLLOFF
#   inflating: AdmixTools-master/README.ROLLOFF_OUTPUT
#   inflating: AdmixTools-master/README.qp4diff
#   inflating: AdmixTools-master/README.qpfstats
#    creating: AdmixTools-master/convertf/
#   inflating: AdmixTools-master/convertf/README
#   inflating: AdmixTools-master/convertf/example.ancestrymapgeno
#  extracting: AdmixTools-master/convertf/example.bed
#   inflating: AdmixTools-master/convertf/example.eigenstratgeno
#   inflating: AdmixTools-master/convertf/example.ind
#   inflating: AdmixTools-master/convertf/example.ind.packedancestrymap
#   inflating: AdmixTools-master/convertf/example.map
#   inflating: AdmixTools-master/convertf/example.packedancestrymap
#   inflating: AdmixTools-master/convertf/example.packedancestrymapgeno
#   inflating: AdmixTools-master/convertf/example.ped
#   inflating: AdmixTools-master/convertf/example.pedind
#   inflating: AdmixTools-master/convertf/example.pedsnp
#   inflating: AdmixTools-master/convertf/example.perl
#  extracting: AdmixTools-master/convertf/example.pheno
#   inflating: AdmixTools-master/convertf/example.snp
#   inflating: AdmixTools-master/convertf/example.snp.packedancestrymap
#   inflating: AdmixTools-master/convertf/ind2pheno.perl
#   inflating: AdmixTools-master/convertf/par.ANCESTRYMAP.EIGENSTRAT
#   inflating: AdmixTools-master/convertf/par.EIGENSTRAT.PED
#   inflating: AdmixTools-master/convertf/par.PACKEDANCESTRYMAP.ANCESTRYMAP
#   inflating: AdmixTools-master/convertf/par.PACKEDPED.PACKEDANCESTRYMAP
#   inflating: AdmixTools-master/convertf/par.PED.EIGENSTRAT
#   inflating: AdmixTools-master/convertf/par.PED.PACKEDPED
#    creating: AdmixTools-master/examples.qpGraph/
#   inflating: AdmixTools-master/examples.qpGraph/gr1triv
#   inflating: AdmixTools-master/examples.qpGraph/gr1x
#   inflating: AdmixTools-master/examples.qpGraph/gr1x.oroot
#  extracting: AdmixTools-master/examples.qpGraph/gr1x:log:nullout
#   inflating: AdmixTools-master/examples.qpGraph/par:sim1:gr1triv
#   inflating: AdmixTools-master/examples.qpGraph/par:sim1:gr1x
#   inflating: AdmixTools-master/examples.qpGraph/par:sim1:gr1x:2
#   inflating: AdmixTools-master/examples.qpGraph/par:sim1:gr1x:nullout
#   inflating: AdmixTools-master/examples.qpGraph/parsimp.templ
#   inflating: AdmixTools-master/examples.qpGraph/parsimp2.templ
#   inflating: AdmixTools-master/examples.qpGraph/runit
#   inflating: AdmixTools-master/examples.qpGraph/runqpgf
#   inflating: AdmixTools-master/examples.qpGraph/runqpgf2
#   inflating: AdmixTools-master/examples.qpGraph/runqpreroot
#    creating: AdmixTools-master/examples/
#   inflating: AdmixTools-master/examples/README
#   inflating: AdmixTools-master/examples/expfit_Uygur.flog
#   inflating: AdmixTools-master/examples/gr1triv:log
#   inflating: AdmixTools-master/examples/gr1x:2:log
#   inflating: AdmixTools-master/examples/gr1x:log
#  extracting: AdmixTools-master/examples/left1
#   inflating: AdmixTools-master/examples/list_qp3Pop
#   inflating: AdmixTools-master/examples/list_qp4diff
#   inflating: AdmixTools-master/examples/list_qpBound
#   inflating: AdmixTools-master/examples/list_qpDpart
#  extracting: AdmixTools-master/examples/list_qpDstat
#   inflating: AdmixTools-master/examples/list_qpDstat1
#   inflating: AdmixTools-master/examples/list_qpF4ratio
#   inflating: AdmixTools-master/examples/mklog
#   inflating: AdmixTools-master/examples/parRolloff
#   inflating: AdmixTools-master/examples/parqp3Pop
#   inflating: AdmixTools-master/examples/parqp4diff
#   inflating: AdmixTools-master/examples/parqp4diffa
#   inflating: AdmixTools-master/examples/parqpAdm
#   inflating: AdmixTools-master/examples/parqpBound
#   inflating: AdmixTools-master/examples/parqpDpart
#   inflating: AdmixTools-master/examples/parqpDstat
#   inflating: AdmixTools-master/examples/parqpDstat1
#   inflating: AdmixTools-master/examples/parqpF4ratio
#   inflating: AdmixTools-master/examples/parqpWave
#   inflating: AdmixTools-master/examples/parqpff3
#   inflating: AdmixTools-master/examples/plist
#   inflating: AdmixTools-master/examples/q1
#   inflating: AdmixTools-master/examples/q2
#   inflating: AdmixTools-master/examples/qp3Pop.log
#   inflating: AdmixTools-master/examples/qp4diff.log
#   inflating: AdmixTools-master/examples/qpAdm.log
#   inflating: AdmixTools-master/examples/qpBound.log
#   inflating: AdmixTools-master/examples/qpDstat.log
#   inflating: AdmixTools-master/examples/qpDstat1.log
#   inflating: AdmixTools-master/examples/qpF4ratio.log
#   inflating: AdmixTools-master/examples/qpWave.log
#   inflating: AdmixTools-master/examples/right1
#   inflating: AdmixTools-master/examples/rolloff.par
#  extracting: AdmixTools-master/examples/rolloff.ref
#  extracting: AdmixTools-master/examples/rolloff.target
#   inflating: AdmixTools-master/examples/xx:qp4diff
#   inflating: AdmixTools-master/examples/xx:qp4diffa
#   inflating: AdmixTools-master/examples/xx:qpff3
#   inflating: AdmixTools-master/fancy.txt
#   inflating: AdmixTools-master/halfscore.pdf
#   inflating: AdmixTools-master/pdoc.pdf
#   inflating: AdmixTools-master/pdoc.tex
#    creating: AdmixTools-master/perlsrc/
#   inflating: AdmixTools-master/perlsrc/dof4
#   inflating: AdmixTools-master/perlsrc/dof4a
#   inflating: AdmixTools-master/perlsrc/getresult
#   inflating: AdmixTools-master/perlsrc/jackdiff
#   inflating: AdmixTools-master/perlsrc/mkpretty
#   inflating: AdmixTools-master/perlsrc/numlines
#   inflating: AdmixTools-master/perlsrc/xtractcol
#   inflating: AdmixTools-master/perlsrc/xtractcolv
#    creating: AdmixTools-master/perlsrc2/
#   inflating: AdmixTools-master/perlsrc2/dof4
#   inflating: AdmixTools-master/perlsrc2/getresult
#   inflating: AdmixTools-master/perlsrc2/jackdiff
#   inflating: AdmixTools-master/perlsrc2/mkpretty
#   inflating: AdmixTools-master/perlsrc2/xtractcol
#   inflating: AdmixTools-master/qpGraph_hints.txt
#   inflating: AdmixTools-master/qpfs.pdf
#    creating: AdmixTools-master/src/
#   inflating: AdmixTools-master/src/.gitignore
#   inflating: AdmixTools-master/src/LICENSE.txt
#   inflating: AdmixTools-master/src/Makefile
#   inflating: AdmixTools-master/src/Makefile.mac
#   inflating: AdmixTools-master/src/add_extern_C.sh
#   inflating: AdmixTools-master/src/admutils.c
#   inflating: AdmixTools-master/src/admutils.h
#   inflating: AdmixTools-master/src/badpairs.h
#   inflating: AdmixTools-master/src/convertf.c
#   inflating: AdmixTools-master/src/dowtjack.c
#   inflating: AdmixTools-master/src/egsubs.c
#   inflating: AdmixTools-master/src/egsubs.h
#   inflating: AdmixTools-master/src/eigqpsubs.h
#   inflating: AdmixTools-master/src/eigsubs.c
#   inflating: AdmixTools-master/src/eigsubs.h
#   inflating: AdmixTools-master/src/eigx.c
#   inflating: AdmixTools-master/src/exclude.c
#   inflating: AdmixTools-master/src/exclude.h
#   inflating: AdmixTools-master/src/expfit.templ
#   inflating: AdmixTools-master/src/f4rank.c
#   inflating: AdmixTools-master/src/f4rank.h
#   inflating: AdmixTools-master/src/faidx.h
#   inflating: AdmixTools-master/src/fitsubs.h
#   inflating: AdmixTools-master/src/fourier.c
#   inflating: AdmixTools-master/src/fstats.c
#   inflating: AdmixTools-master/src/gcount.c
#   inflating: AdmixTools-master/src/globals.h
#   inflating: AdmixTools-master/src/grabpars.c
#   inflating: AdmixTools-master/src/gslkim.c
#   inflating: AdmixTools-master/src/gslqp.c
#   inflating: AdmixTools-master/src/h2d.c
#   inflating: AdmixTools-master/src/h2d.h
#   inflating: AdmixTools-master/src/kimf.c
#   inflating: AdmixTools-master/src/kimqpg.c
#   inflating: AdmixTools-master/src/kimqpr.c
#   inflating: AdmixTools-master/src/ldsubs.c
#   inflating: AdmixTools-master/src/ldsubs.h
#   inflating: AdmixTools-master/src/mcio.c
#   inflating: AdmixTools-master/src/mcio.h
#   inflating: AdmixTools-master/src/mcmcpars.h
#   inflating: AdmixTools-master/src/mergeit.c
#   inflating: AdmixTools-master/src/nagqp.c
#   inflating: AdmixTools-master/src/nagsubs.c
#   inflating: AdmixTools-master/src/nagsubs.h
#   inflating: AdmixTools-master/src/nicklib.h
#   inflating: AdmixTools-master/src/nicksam.h
#    creating: AdmixTools-master/src/nicksrc/
#  extracting: AdmixTools-master/src/nicksrc/.gitignore
#   inflating: AdmixTools-master/src/nicksrc/LICENSE.txt
#   inflating: AdmixTools-master/src/nicksrc/Makefile
#   inflating: AdmixTools-master/src/nicksrc/esttime2.c
#   inflating: AdmixTools-master/src/nicksrc/gauss.c
#   inflating: AdmixTools-master/src/nicksrc/gcd.c
#   inflating: AdmixTools-master/src/nicksrc/gds.c
#   inflating: AdmixTools-master/src/nicksrc/getpars.c
#   inflating: AdmixTools-master/src/nicksrc/getpars.h
#   inflating: AdmixTools-master/src/nicksrc/kimf.c
#   inflating: AdmixTools-master/src/nicksrc/linmake
#   inflating: AdmixTools-master/src/nicksrc/linsolve.c
#   inflating: AdmixTools-master/src/nicksrc/linsubs.c
#   inflating: AdmixTools-master/src/nicksrc/linsubs.h
#   inflating: AdmixTools-master/src/nicksrc/mptable.h
#   inflating: AdmixTools-master/src/nicksrc/nicklib.h
#   inflating: AdmixTools-master/src/nicksrc/qdiff
#   inflating: AdmixTools-master/src/nicksrc/ranmath.h
#   inflating: AdmixTools-master/src/nicksrc/sortit.c
#   inflating: AdmixTools-master/src/nicksrc/sortit.h
#   inflating: AdmixTools-master/src/nicksrc/statsubs.c
#   inflating: AdmixTools-master/src/nicksrc/statsubs.h
#   inflating: AdmixTools-master/src/nicksrc/strsubs.c
#   inflating: AdmixTools-master/src/nicksrc/strsubs.h
#   inflating: AdmixTools-master/src/nicksrc/twtable.h
#   inflating: AdmixTools-master/src/nicksrc/vsubs.c
#   inflating: AdmixTools-master/src/nicksrc/vsubs.h
#   inflating: AdmixTools-master/src/nicksrc/xsearch.c
#   inflating: AdmixTools-master/src/nicksrc/xsearch.h
#   inflating: AdmixTools-master/src/packit.h
#   inflating: AdmixTools-master/src/qfstats1
#   inflating: AdmixTools-master/src/qp3Pop.c
#   inflating: AdmixTools-master/src/qp4diff.c
#   inflating: AdmixTools-master/src/qpAdm.c
#   inflating: AdmixTools-master/src/qpBound.c
#   inflating: AdmixTools-master/src/qpDpart.c
#   inflating: AdmixTools-master/src/qpDstat.c
#   inflating: AdmixTools-master/src/qpF4ratio.c
#   inflating: AdmixTools-master/src/qpGraph.c
#   inflating: AdmixTools-master/src/qpWave.c
#   inflating: AdmixTools-master/src/qpdslow.c
#   inflating: AdmixTools-master/src/qpff3base.c
#   inflating: AdmixTools-master/src/qpfmv.c
#   inflating: AdmixTools-master/src/qpfstats.c
#   inflating: AdmixTools-master/src/qpgsubs.c
#   inflating: AdmixTools-master/src/qpgsubs.h
#   inflating: AdmixTools-master/src/qpmix.c
#   inflating: AdmixTools-master/src/qpreroot.c
#   inflating: AdmixTools-master/src/qpsubs.c
#   inflating: AdmixTools-master/src/qpsubs.h
#   inflating: AdmixTools-master/src/qpsubsarti.c
#   inflating: AdmixTools-master/src/qsubs.h
#   inflating: AdmixTools-master/src/regsubs.c
#   inflating: AdmixTools-master/src/regsubs.h
#   inflating: AdmixTools-master/src/rexpfit.r
#   inflating: AdmixTools-master/src/rolloff.c
#   inflating: AdmixTools-master/src/rolloffp.c
#   inflating: AdmixTools-master/src/simpjack2.c
#   inflating: AdmixTools-master/src/strsubs.h
#   inflating: AdmixTools-master/src/twtable
#   inflating: AdmixTools-master/src/wtjack.pl
#   inflating: AdmixTools-master/src/xpsubs.h
#   inflating: AdmixTools-master/src/xqpsubs.c

# %%
cd AdmixTools-master/src
# Out:
# /content/AdmixTools-master/src

# %%
# !sudo apt-get install build-essential
# !sudo apt-get install libgsl-dev
# !sudo apt-get install libopenblas-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# 0 upgraded, 0 newly installed, 0 to remove and 46 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libgsl27 libgslcblas0
# Suggested packages:
#   gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info | gsl-ref-html
# The following NEW packages will be installed:
#   libgsl-dev libgsl27 libgslcblas0
# 0 upgraded, 3 newly installed, 0 to remove and 46 not upgraded.
# Need to get 2,351 kB of archives.
# After this operation, 10.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgslcblas0 amd64 2.7.1+dfsg-3 [94.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgsl27 amd64 2.7.1+dfsg-3 [1,000 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgsl-dev amd64 2.7.1+dfsg-3 [1,257 kB]
# Fetched 2,351 kB in 1s (2,587 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libgslcblas0:amd64.
# (Reading database ... 123576 files and directories currently installed.)
# Preparing to unpack .../libgslcblas0_2.7.1+dfsg-3_amd64.deb ...
# Unpacking libgslcblas0:amd64 (2.7.1+dfsg-3) ...
# Selecting previously unselected package libgsl27:amd64.
# Preparing to unpack .../libgsl27_2.7.1+dfsg-3_amd64.deb ...
# Unpacking libgsl27:amd64 (2.7.1+dfsg-3) ...
# Selecting previously unselected package libgsl-dev.
# Preparing to unpack .../libgsl-dev_2.7.1+dfsg-3_amd64.deb ...
# Unpacking libgsl-dev (2.7.1+dfsg-3) ...
# Setting up libgslcblas0:amd64 (2.7.1+dfsg-3) ...
# Setting up libgsl27:amd64 (2.7.1+dfsg-3) ...
# Setting up libgsl-dev (2.7.1+dfsg-3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libopenblas-dev is already the newest version (0.3.20+ds-1).
# 0 upgraded, 0 newly installed, 0 to remove and 46 not upgraded.

# %%
# !make clobber
# !make all
# !make install
# Out:
# rm -f *.o
# rm -f *junk*
# rm -f core
# make -C nicksrc clean
# make[1]: Entering directory '/content/AdmixTools-master/src/nicksrc'
# rm -f *.o
# rm -f libnick.a
# make[1]: Leaving directory '/content/AdmixTools-master/src/nicksrc'
# rm -f qp3Pop qpDstat qpF4ratio qpAdm qpWave qp4diff qpdslow dowtjack expfit.sh  qpBound qpGraph qpreroot qpff3base qpDpart qpfstats qpfmv qpmix
# rm -f rolloff rolloffp convertf mergeit simpjack2 grabpars kimf gcount
# rm -rf /content/AdmixTools-master/src/admixtables
# rm -f tables
# rm -f ../bin/*
# make -C nicksrc
# make[1]: Entering directory '/content/AdmixTools-master/src/nicksrc'
# cc -c -g -p -Wimplicit -I./   -c -o strsubs.o strsubs.c
# cc -c -g -p -Wimplicit -I./   -c -o sortit.o sortit.c
# cc -c -g -p -Wimplicit -I./   -c -o vsubs.o vsubs.c
# cc -c -g -p -Wimplicit -I./   -c -o statsubs.o statsubs.c
# cc -c -g -p -Wimplicit -I./   -c -o linsubs.o linsubs.c
# cc -c -g -p -Wimplicit -I./   -c -o getpars.o getpars.c
# cc -c -g -p -Wimplicit -I./   -c -o xsearch.o xsearch.c
# cc -c -g -p -Wimplicit -I./   -c -o gauss.o gauss.c
# cc -c -g -p -Wimplicit -I./   -c -o gds.o gds.c
# ar -r libnick.a strsubs.o sortit.o vsubs.o statsubs.o linsubs.o getpars.o xsearch.o gauss.o gds.o
# ar: creating libnick.a
# ranlib libnick.a
# make[1]: Leaving directory '/content/AdmixTools-master/src/nicksrc'
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qp3Pop.o qp3Pop.c
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpsubs.o qpsubs.c
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o mcio.o mcio.c
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o ldsubs.o ldsubs.c
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o admutils.o admutils.c
# admutils.c: In function ‘setid2pops’:
# admutils.c:1114:28: warning: format ‘%s’ expects a matching ‘char *’ argument [-Wformat=]
#  1114 |     printf("(setid2pops): %s not found\n") ;
#       |                           ~^
#       |                            |
#       |                            char *
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o egsubs.o egsubs.c
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o regsubs.o regsubs.c
# cc -g  -L./nicksrc  qp3Pop.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qp3Pop
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpDstat.o qpDstat.c
# cc -g  -L./nicksrc  qpDstat.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qpDstat
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpF4ratio.o qpF4ratio.c
# cc -g  -L./nicksrc  qpF4ratio.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qpF4ratio
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpAdm.o qpAdm.c
# qpAdm.c: In function ‘mkfstats’:
# qpAdm.c:1797:69: warning: ‘%s’ directive writing up to 255 bytes into a region of size 205 [-Wformat-overflow=]
#  1797 |  sprintf(sss, "fgrep -v fstatsoutname: %s | fgrep -v poplistname: > %s", parname, tpar) ;
#       |                                                                     ^~            ~~~~
# qpAdm.c:1797:2: note: ‘sprintf’ output 52 or more bytes (assuming 307) into a destination of size 256
#  1797 |  sprintf(sss, "fgrep -v fstatsoutname: %s | fgrep -v poplistname: > %s", parname, tpar) ;
#       |  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# qpAdm.c:1811:28: warning: ‘%s’ directive writing up to 255 bytes into a region of size 244 [-Wformat-overflow=]
#  1811 |  sprintf(sss, "qpfstats -p %s > %s", ppp, fslog) ;
#       |                            ^~        ~~~
# qpAdm.c:1811:2: note: ‘sprintf’ output between 16 and 526 bytes into a destination of size 256
#  1811 |  sprintf(sss, "qpfstats -p %s > %s", ppp, fslog) ;
#       |  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# qpAdm.c:1819:20: warning: ‘%s’ directive writing up to 255 bytes into a region of size 253 [-Wformat-overflow=]
#  1819 |   sprintf(sss, "cp %s %s", fsx, fstatsoutname) ;
#       |                    ^~      ~~~
# qpAdm.c:1819:3: note: ‘sprintf’ output 5 or more bytes (assuming 260) into a destination of size 256
#  1819 |   sprintf(sss, "cp %s %s", fsx, fstatsoutname) ;
#       |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o f4rank.o f4rank.c
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o eigsubs.o eigsubs.c
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o eigx.o eigx.c
# cc -g  -L./nicksrc  qpAdm.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o f4rank.o eigsubs.o eigx.o  -lgsl -lopenblas -lm -lnick -o qpAdm
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpWave.o qpWave.c
# qpWave.c: In function ‘mkfstats’:
# qpWave.c:811:69: warning: ‘%s’ directive writing up to 255 bytes into a region of size 205 [-Wformat-overflow=]
#   811 |  sprintf(sss, "fgrep -v fstatsoutname: %s | fgrep -v poplistname: > %s", parname, tpar) ;
#       |                                                                     ^~            ~~~~
# qpWave.c:811:2: note: ‘sprintf’ output 52 or more bytes (assuming 307) into a destination of size 256
#   811 |  sprintf(sss, "fgrep -v fstatsoutname: %s | fgrep -v poplistname: > %s", parname, tpar) ;
#       |  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# qpWave.c:825:28: warning: ‘%s’ directive writing up to 255 bytes into a region of size 244 [-Wformat-overflow=]
#   825 |  sprintf(sss, "qpfstats -p %s > %s", ppp, fslog) ;
#       |                            ^~        ~~~
# qpWave.c:825:2: note: ‘sprintf’ output between 16 and 526 bytes into a destination of size 256
#   825 |  sprintf(sss, "qpfstats -p %s > %s", ppp, fslog) ;
#       |  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# qpWave.c:833:20: warning: ‘%s’ directive writing up to 255 bytes into a region of size 253 [-Wformat-overflow=]
#   833 |   sprintf(sss, "cp %s %s", fsx, fstatsoutname) ;
#       |                    ^~      ~~~
# qpWave.c:833:3: note: ‘sprintf’ output 5 or more bytes (assuming 260) into a destination of size 256
#   833 |   sprintf(sss, "cp %s %s", fsx, fstatsoutname) ;
#       |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cc -g  -L./nicksrc  qpWave.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o f4rank.o eigsubs.o eigx.o  -lgsl -lopenblas -lm -lnick -o qpWave
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qp4diff.o qp4diff.c
# cc -g  -L./nicksrc  qp4diff.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qp4diff
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpdslow.o qpdslow.c
# cc -g  -L./nicksrc  qpdslow.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qpdslow
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o dowtjack.o dowtjack.c
# cc -g  -L./nicksrc  dowtjack.o nicksrc/libnick.a  -lgsl -lopenblas -lm -lnick -o dowtjack
# sed -e "s&BBBIN&/content/AdmixTools-master/src/../bin&" < expfit.templ > expfit.sh
# chmod +x expfit.sh
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpBound.o qpBound.c
# cc -g  -L./nicksrc  qpBound.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qpBound
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpGraph.o qpGraph.c
# qpGraph.c: In function ‘printfit’:
# qpGraph.c:1531:21: warning: ‘%s’ directive writing up to 511 bytes into a region of size 509 [-Wformat-overflow=]
#  1531 |   sprintf(ss, "%s ::%s\n", graphname, ssworst) ;
#       |                     ^~                ~~~~~~~
# qpGraph.c:1531:3: note: ‘sprintf’ output 5 or more bytes (assuming 516) into a destination of size 512
#  1531 |   sprintf(ss, "%s ::%s\n", graphname, ssworst) ;
#       |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# qpGraph.c: In function ‘mkfstats’:
# qpGraph.c:2928:69: warning: ‘%s’ directive writing up to 127 bytes into a region of size 77 [-Wformat-overflow=]
#  2928 |  sprintf(sss, "fgrep -v fstatsoutname: %s | fgrep -v poplistname: > %s", parname, tpar) ;
#       |                                                                     ^~            ~~~~
# qpGraph.c:2928:2: note: ‘sprintf’ output 52 or more bytes (assuming 179) into a destination of size 128
#  2928 |  sprintf(sss, "fgrep -v fstatsoutname: %s | fgrep -v poplistname: > %s", parname, tpar) ;
#       |  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# qpGraph.c:2946:28: warning: ‘%s’ directive writing up to 127 bytes into a region of size 116 [-Wformat-overflow=]
#  2946 |  sprintf(sss, "qpfstats -p %s > /tmp/qqlog:%d", ppp, pid) ;
#       |                            ^~                   ~~~
# qpGraph.c:2946:2: note: ‘sprintf’ output between 28 and 165 bytes into a destination of size 128
#  2946 |  sprintf(sss, "qpfstats -p %s > /tmp/qqlog:%d", ppp, pid) ;
#       |  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# qpGraph.c:2950:20: warning: ‘%s’ directive writing up to 127 bytes into a region of size 125 [-Wformat-overflow=]
#  2950 |   sprintf(sss, "cp %s %s", fsx, fstatsoutname) ;
#       |                    ^~      ~~~
# qpGraph.c:2950:3: note: ‘sprintf’ output 5 or more bytes (assuming 132) into a destination of size 128
#  2950 |   sprintf(sss, "cp %s %s", fsx, fstatsoutname) ;
#       |   ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o gslqp.o gslqp.c
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpgsubs.o qpgsubs.c
# qpgsubs.c: In function ‘printedgedata’:
# qpgsubs.c:391:14: warning: format ‘%s’ expects a matching ‘char *’ argument [-Wformat=]
#   391 |   printf("%18s ") ;
#       |           ~~~^
#       |              |
#       |              char *
# cc -g  -L./nicksrc  qpGraph.o nicksrc/libnick.a gslqp.o qpgsubs.o qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qpGraph
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpreroot.o qpreroot.c
# cc -g  -L./nicksrc  qpreroot.o qpgsubs.o qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qpreroot
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpff3base.o qpff3base.c
# cc -g  -L./nicksrc  qpff3base.o nicksrc/libnick.a qpgsubs.o qpsubs.o mcio.o admutils.o egsubs.o regsubs.o ldsubs.o  -lgsl -lopenblas -lm -lnick -o qpff3base
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpDpart.o qpDpart.c
# cc -g  -L./nicksrc  qpDpart.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qpDpart
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpfstats.o qpfstats.c
# cc -g  -L./nicksrc  qpfstats.o nicksrc/libnick.a qpgsubs.o qpsubs.o mcio.o admutils.o egsubs.o regsubs.o ldsubs.o  -lgsl -lopenblas -lm -lnick -o qpfstats
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpfmv.o qpfmv.c
# cc -g  -L./nicksrc  qpfmv.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o eigsubs.o eigx.o  -lgsl -lopenblas -lm -lnick -o qpfmv
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o qpmix.o qpmix.c
# cc -g  -L./nicksrc  qpmix.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o qpmix
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o rolloff.o rolloff.c
# cc -g  -L./nicksrc  rolloff.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o rolloff
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o rolloffp.o rolloffp.c
# rolloffp.c: In function ‘main’:
# rolloffp.c:505:29: warning: format ‘%f’ expects a matching ‘double’ argument [-Wformat=]
#   505 |        printf(" %12.6f %12.6f", xnum[s]/znum[s]) ;
#       |                        ~~~~~^
#       |                             |
#       |                             double
# rolloffp.c:506:29: warning: format ‘%f’ expects a matching ‘double’ argument [-Wformat=]
#   506 |        printf(" %12.6f %12.6f", xden[s]/zden[s]) ;
#       |                        ~~~~~^
#       |                             |
#       |                             double
# cc -g  -L./nicksrc  rolloffp.o nicksrc/libnick.a qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o rolloffp
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o convertf.o convertf.c
# convertf.c: In function ‘main’:
# convertf.c:432:58: warning: format ‘%f’ expects a matching ‘double’ argument [-Wformat=]
#   432 |  if (makemiss > 0) printf("forcing missing with prob: %9.f\n") ;
#       |                                                       ~~~^
#       |                                                          |
#       |                                                          double
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o h2d.o h2d.c
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o exclude.o exclude.c
# cc -g  -L./nicksrc  convertf.o nicksrc/libnick.a mcio.o admutils.o egsubs.o h2d.o exclude.o  -lgsl -lopenblas -lm -lnick -o convertf
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o mergeit.o mergeit.c
# cc -g  -L./nicksrc  mergeit.o nicksrc/libnick.a mcio.o admutils.o egsubs.o h2d.o exclude.o  -lgsl -lopenblas -lm -lnick -o mergeit
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o simpjack2.o simpjack2.c
# cc -g  -L./nicksrc  simpjack2.o nicksrc/libnick.a  -lgsl -lopenblas -lm -lnick -o simpjack2
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o grabpars.o grabpars.c
# cc -g  -L./nicksrc  grabpars.o nicksrc/libnick.a  -lgsl -lopenblas -lm -lnick -o grabpars
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o kimf.o kimf.c
# kimf.c: In function ‘alloc_cl’:
# kimf.c:1645:61: warning: format ‘%x’ expects argument of type ‘unsigned int’, but argument 5 has type ‘void *’ [-Wformat=]
#  1645 |   if (verbose) printf("largeliter: %d  xcload xchit: %d %d %x score: %12.6f\n", largeliter, xcload, xchit, topheap(), lastkimscore) ;
#       |                                                            ~^                                              ~~~~~~~~~
#       |                                                             |                                              |
#       |                                                             unsigned int                                   void *
#       |                                                            %p
# kimf.c: In function ‘bprob1_admix’:
# kimf.c:1953:44: warning: format ‘%f’ expects a matching ‘double’ argument [-Wformat=]
#  1953 |      printf("zz3 %15.9f %12.6f %12.6f %12.6f %12.6f\n", y2, y1,  y1*y2) ;
#       |                                       ~~~~~^
#       |                                            |
#       |                                            double
# kimf.c:1953:51: warning: format ‘%f’ expects a matching ‘double’ argument [-Wformat=]
#  1953 |      printf("zz3 %15.9f %12.6f %12.6f %12.6f %12.6f\n", y2, y1,  y1*y2) ;
#       |                                              ~~~~~^
#       |                                                   |
#       |                                                   double
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o gslkim.o gslkim.c
# gslkim.c: In function ‘gslopt’:
# gslkim.c:120:26: warning: format ‘%x’ expects argument of type ‘unsigned int’, but argument 2 has type ‘void *’ [-Wformat=]
#   120 |         printf("zzheap: %x\n", topheap()) ;
#       |                         ~^     ~~~~~~~~~
#       |                          |     |
#       |                          |     void *
#       |                          unsigned int
#       |                         %p
# cc -g  -L./nicksrc  kimf.o gslkim.o qpgsubs.o qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o kimf
# cc -c -g -p -pg -Wimplicit -I./ -I./nicksrc   -c -o gcount.o gcount.c
# cc -g  -L./nicksrc  gcount.o qpsubs.o mcio.o ldsubs.o admutils.o egsubs.o regsubs.o  -lgsl -lopenblas -lm -lnick -o gcount
# mkdir -p  /content/AdmixTools-master/src/admixtables
# echo "tables made"  > tables
# cp twtable  /content/AdmixTools-master/src/admixtables
# mkdir -p ../bin
# cp qp3Pop qpDstat qpF4ratio qpAdm qpWave qp4diff qpdslow dowtjack expfit.sh  qpBound qpGraph qpreroot qpff3base qpDpart qpfstats qpfmv qpmix ../bin
# cp rexpfit.r  wtjack.pl  ../bin
# cp rolloff rolloffp convertf mergeit simpjack2 grabpars kimf gcount  ../bin
# cp ../perlsrc/* ../bin

# %%
cd ../bin
# Out:
# /content/AdmixTools-master/bin

# %% [markdown]
# # Prepare Reich dataset

# %%
# !ls
# Out:
# convertf  expfit.sh  jackdiff  numlines  qpBound  qpF4ratio  qpGraph   rexpfit.r  wtjack.pl
# dof4	  gcount     kimf      qp3Pop	 qpDpart  qpff3base  qpmix     rolloff	  xtractcol
# dof4a	  getresult  mergeit   qp4diff	 qpdslow  qpfmv      qpreroot  rolloffp   xtractcolv
# dowtjack  grabpars   mkpretty  qpAdm	 qpDstat  qpfstats   qpWave    simpjack2

# %%
# !wget https://reichdata.hms.harvard.edu/pub/datasets/amh_repo/curated_releases/V54/V54.1.p1/SHARE/public.dir/v54.1.p1_1240K_public.tar
# !tar -xvf v54.1.p1_1240K_public.tar
# Out:
# --2024-07-16 07:41:45--  https://reichdata.hms.harvard.edu/pub/datasets/amh_repo/curated_releases/V54/V54.1.p1/SHARE/public.dir/v54.1.p1_1240K_public.tar
# Resolving reichdata.hms.harvard.edu (reichdata.hms.harvard.edu)... 134.174.159.103
# Connecting to reichdata.hms.harvard.edu (reichdata.hms.harvard.edu)|134.174.159.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5137612800 (4.8G) [application/x-tar]
# Saving to: ‘v54.1.p1_1240K_public.tar’
#
# v54.1.p1_1240K_publ 100%[===================>]   4.78G  46.6MB/s    in 1m 59s
#
# 2024-07-16 07:43:45 (41.2 MB/s) - ‘v54.1.p1_1240K_public.tar’ saved [5137612800/5137612800]
#
# v54.1.p1_1240K_public.anno
# v54.1.p1_1240K_public.geno
# v54.1.p1_1240K_public.snp
# v54.1.p1_1240K_public.ind

# %%
import os

# Define the path to the new folder
new_folder_path = '/content/AdmixTools-master/bin/dataset'

# Create the new folder
os.makedirs(new_folder_path, exist_ok=True)

# Verify the folder creation
if os.path.exists(new_folder_path):
    print(f"Folder '{new_folder_path}' created successfully!")
else:
    print(f"Failed to create folder '{new_folder_path}'.")
# Out:
# Folder '/content/AdmixTools-master/bin/dataset' created successfully!

# %%
import os
import shutil

# Define the paths of the files to be moved
files_to_move = [
    '/content/AdmixTools-master/bin/v54.1.p1_1240K_public.anno',
    '/content/AdmixTools-master/bin/v54.1.p1_1240K_public.geno',
    '/content/AdmixTools-master/bin/v54.1.p1_1240K_public.ind',
    '/content/AdmixTools-master/bin/v54.1.p1_1240K_public.snp'
]

# Define the destination folder
destination_folder = '/content/AdmixTools-master/bin/dataset'

# Create the destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# Move each file to the destination folder
for file_path in files_to_move:
    shutil.move(file_path, destination_folder)

# Verify the move operation
moved_files = os.listdir(destination_folder)
print("Files moved to the new folder:", moved_files)
# Out:
# Files moved to the new folder: ['v54.1.p1_1240K_public.geno', 'v54.1.p1_1240K_public.snp', 'v54.1.p1_1240K_public.anno', 'v54.1.p1_1240K_public.ind']

# %%
#inside of bin/dataset
# !ls
# Out:
# convertf  expfit.sh  kimf      qp4diff	qpDstat    qpGraph    rolloff			 xtractcol
# dataset   gcount     mergeit   qpAdm	qpF4ratio  qpmix      rolloffp			 xtractcolv
# dof4	  getresult  mkpretty  qpBound	qpff3base  qpreroot   simpjack2
# dof4a	  grabpars   numlines  qpDpart	qpfmv	   qpWave     v54.1.p1_1240K_public.tar
# dowtjack  jackdiff   qp3Pop    qpdslow	qpfstats   rexpfit.r  wtjack.pl

# %%
cd dataset/
# Out:
# /content/AdmixTools-master/bin/dataset

# %%
# !ls
# Out:
# v54.1.p1_1240K_public.anno  v54.1.p1_1240K_public.ind
# v54.1.p1_1240K_public.geno  v54.1.p1_1240K_public.snp

# %%
cd ..
# Out:
# /content/AdmixTools-master/bin

# %%
# !ls
# Out:
# convertf  expfit.sh  kimf      qp4diff	qpDstat    qpGraph    rolloff			 xtractcol
# dataset   gcount     mergeit   qpAdm	qpF4ratio  qpmix      rolloffp			 xtractcolv
# dof4	  getresult  mkpretty  qpBound	qpff3base  qpreroot   simpjack2
# dof4a	  grabpars   numlines  qpDpart	qpfmv	   qpWave     v54.1.p1_1240K_public.tar
# dowtjack  jackdiff   qp3Pop    qpdslow	qpfstats   rexpfit.r  wtjack.pl

# %%
import subprocess

# Define the path to the executable
executable_path = '/content/AdmixTools-master/bin/qpAdm'

# Run the executable
result = subprocess.run([executable_path], capture_output=True, text=True)

# Print the output
print(result.stdout)
print(result.stderr)
# Out:
# Usage: qpAdm [options] <file>
#    -h          ... Print this message and exit.
#    -p <file>   ... use parameters from <file> .
#    -v          ... print version and exit.
#    -V          ... toggle verbose mode ON.
#    -V          ... toggle details mode ON.

# %% [markdown]
# #Prepare target data

# %%
# Install required libraries (if not already installed)
# !apt-get install -y libgsl-dev libopenblas-dev git

# Download and unzip PLINK
# !wget https://s3.amazonaws.com/plink1-assets/plink_linux_x86_64_20231211.zip
# !unzip plink_linux_x86_64_20231211.zip
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgsl-dev is already the newest version (2.7.1+dfsg-3).
# libopenblas-dev is already the newest version (0.3.20+ds-1).
# git is already the newest version (1:2.34.1-1ubuntu1.11).
# 0 upgraded, 0 newly installed, 0 to remove and 46 not upgraded.
# --2024-07-16 07:46:19--  https://s3.amazonaws.com/plink1-assets/plink_linux_x86_64_20231211.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.92.246, 52.217.196.0, 52.217.206.88, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.92.246|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8953953 (8.5M) [application/zip]
# Saving to: ‘plink_linux_x86_64_20231211.zip’
#
# plink_linux_x86_64_ 100%[===================>]   8.54M  14.9MB/s    in 0.6s
#
# 2024-07-16 07:46:20 (14.9 MB/s) - ‘plink_linux_x86_64_20231211.zip’ saved [8953953/8953953]
#
# Archive:  plink_linux_x86_64_20231211.zip
#   inflating: plink
#   inflating: LICENSE
#   inflating: toy.ped
#   inflating: toy.map
#   inflating: prettify

# %%
# Add the genome.txt in bin foler

# %%
# !ls
# Out:
# convertf    grabpars			     prettify	qpff3base  rolloffp
# dataset     jackdiff			     qp3Pop	qpfmv	   simpjack2
# dof4	    kimf			     qp4diff	qpfstats   toy.map
# dof4a	    LICENSE			     qpAdm	qpGraph    toy.ped
# dowtjack    mergeit			     qpBound	qpmix	   v54.1.p1_1240K_public.tar
# expfit.sh   mkpretty			     qpDpart	qpreroot   wtjack.pl
# gcount	    numlines			     qpdslow	qpWave	   xtractcol
# genome.txt  plink			     qpDstat	rexpfit.r  xtractcolv
# getresult   plink_linux_x86_64_20231211.zip  qpF4ratio	rolloff

# %% [markdown]
# # Make sure the genotype colum has only two alleles not more.

# %%
# !./plink --23file genome.txt Yusup R --make-bed --out Genome_merged
# Out:
# PLINK v1.90b7.2 64-bit (11 Dec 2023)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Genome_merged.log.
# Options in effect:
#   --23file genome.txt Yusup R
#   --make-bed
#   --out Genome_merged
#
# 12978 MB RAM detected; reserving 6489 MB for main workspace.
# --23file: Genome_merged-temporary.bed + Genome_merged-temporary.bim +
# Genome_merged-temporary.fam written.
# Inferred sex: female.
# 604147 variants loaded from .bim file.
# 1 person (0 males, 1 female) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1 founder and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.894006.
# 604147 variants and 1 person pass filters and QC.
# Note: No phenotypes present.
# --make-bed to Genome_merged.bed + Genome_merged.bim + Genome_merged.fam ...
# done.

# %%
# !./plink --bfile Genome_merged  --set-hh-missing --make-bed --out Genome_merged_hh
# Out:
# PLINK v1.90b7.2 64-bit (11 Dec 2023)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2023 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to Genome_merged_hh.log.
# Options in effect:
#   --bfile Genome_merged
#   --make-bed
#   --out Genome_merged_hh
#   --set-hh-missing
#
# 12978 MB RAM detected; reserving 6489 MB for main workspace.
# 604147 variants loaded from .bim file.
# 1 person (0 males, 1 female) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1 founder and 0 nonfounders present.
#  done.
# Total genotyping rate is 0.894006.
# 604147 variants and 1 person pass filters and QC.
# Note: No phenotypes present.
# --make-bed to Genome_merged_hh.bed + Genome_merged_hh.bim +
# done.

# %%
# !wc -l Genome_merged.bim
# Out:
# 604147 Genome_merged.bim

# %%
# !ls
# Out:
# convertf	      Genome_merged_hh.log	       prettify   qpmix
# dataset		      Genome_merged.log		       qp3Pop	  qpreroot
# dof4		      genome.txt		       qp4diff	  qpWave
# dof4a		      getresult			       qpAdm	  rexpfit.r
# dowtjack	      grabpars			       qpBound	  rolloff
# expfit.sh	      jackdiff			       qpDpart	  rolloffp
# gcount		      kimf			       qpdslow	  simpjack2
# Genome_merged.bed     LICENSE			       qpDstat	  toy.map
# Genome_merged.bim     mergeit			       qpF4ratio  toy.ped
# Genome_merged.fam     mkpretty			       qpff3base  v54.1.p1_1240K_public.tar
# Genome_merged_hh.bed  numlines			       qpfmv	  wtjack.pl
# Genome_merged_hh.bim  plink			       qpfstats   xtractcol
# Genome_merged_hh.fam  plink_linux_x86_64_20231211.zip  qpGraph	  xtractcolv

# %% [markdown]
# # prepare convertf_param.par
# ````````````
# genotypename: /content/AdmixTools-master/bin/Genome_merged.bed
# snpname: /content/AdmixTools-master/bin/Genome_merged_hh.bim
# indivname: /content/AdmixTools-master/bin/Genome_merged_hh.fam
# outputformat: EIGENSTRAT
# genotypeoutname: /content/AdmixTools-master/bin/Genome_eigenstrat.geno
# snpoutname: /content/AdmixTools-master/bin/Genome_eigenstrat.snp
# indivoutname: /content/AdmixTools-master/bin/Genome_eigenstrat.ind
# ````````````

# %%
# !ls
# Out:
# convertf	      Genome_merged_hh.log	       qp3Pop	  qpWave
# convertf_param.par    Genome_merged.log		       qp4diff	  rexpfit.r
# dataset		      genome.txt		       qpAdm	  rolloff
# dof4		      getresult			       qpBound	  rolloffp
# dof4a		      grabpars			       qpDpart	  simpjack2
# dowtjack	      jackdiff			       qpdslow	  toy.map
# expfit.sh	      kimf			       qpDstat	  toy.ped
# gcount		      LICENSE			       qpF4ratio  v54.1.p1_1240K_public.tar
# Genome_merged.bed     mergeit			       qpff3base  wtjack.pl
# Genome_merged.bim     mkpretty			       qpfmv	  xtractcol
# Genome_merged.fam     numlines			       qpfstats   xtractcolv
# Genome_merged_hh.bed  plink			       qpGraph
# Genome_merged_hh.bim  plink_linux_x86_64_20231211.zip  qpmix
# Genome_merged_hh.fam  prettify			       qpreroot

# %%
import subprocess

# Define the path to the executable and the parameter file
executable_path = '/content/AdmixTools-master/bin/convertf'
param_file_path = '/content/AdmixTools-master/bin/convertf_param.par'

# Run the executable with the parameter file
result = subprocess.run([executable_path, '-p', param_file_path], capture_output=True, text=True)

# Print the output
print("Standard Output:\n", result.stdout)
print("Standard Error:\n", result.stderr)
# Out:
# Standard Output:
#  parameter file: /content/AdmixTools-master/bin/convertf_param.par
# genotypename: /content/AdmixTools-master/bin/Genome_merged.bed
# snpname: /content/AdmixTools-master/bin/Genome_merged_hh.bim
# indivname: /content/AdmixTools-master/bin/Genome_merged_hh.fam
# outputformat: EIGENSTRAT
# genotypeoutname: /content/AdmixTools-master/bin/Genome_eigenstrat.geno
# snpoutname: /content/AdmixTools-master/bin/Genome_eigenstrat.snp
# indivoutname: /content/AdmixTools-master/bin/Genome_eigenstrat.ind
# ## /content/AdmixTools-master/bin/convertf version: 5722
# genetic distance set from physical distance
# Yusup:R ignored
# all individuals set ignore.  Likely input problem (col 6)
# resetting all individual...
# genotype file processed
# before compress: snps: 604147 indivs: 1
# after compress: snps: 602059 indivs: 1
# numvalidind:      1  maxmiss:  1001
# eigenstrat output
# numsnps output: 602059
# ##end of convertf:        4.929 seconds cpu      372.113 Mbytes in use
#
# Standard Error:

# %%
# !ls
# Out:
# convertf		genome.txt			 qpF4ratio
# convertf_param.par	getresult			 qpff3base
# dataset			grabpars			 qpfmv
# dof4			jackdiff			 qpfstats
# dof4a			kimf				 qpGraph
# dowtjack		LICENSE				 qpmix
# expfit.sh		mergeit				 qpreroot
# gcount			mkpretty			 qpWave
# Genome_eigenstrat.geno	numlines			 rexpfit.r
# Genome_eigenstrat.ind	plink				 rolloff
# Genome_eigenstrat.snp	plink_linux_x86_64_20231211.zip  rolloffp
# Genome_merged.bed	prettify			 simpjack2
# Genome_merged.bim	qp3Pop				 toy.map
# Genome_merged.fam	qp4diff				 toy.ped
# Genome_merged_hh.bed	qpAdm				 v54.1.p1_1240K_public.tar
# Genome_merged_hh.bim	qpBound				 wtjack.pl
# Genome_merged_hh.fam	qpDpart				 xtractcol
# Genome_merged_hh.log	qpdslow				 xtractcolv
# Genome_merged.log	qpDstat

# %% [markdown]
# #prepare merge_param.par
# ```````````
# geno1: /content/AdmixTools-master/bin/dataset/v54.1.p1_1240K_public.geno
# snp1: /content/AdmixTools-master/bin/dataset/v54.1.p1_1240K_public.snp
# ind1: /content/AdmixTools-master/bin/dataset/v54.1.p1_1240K_public.ind
#
# geno2: /content/AdmixTools-master/bin/Genome_eigenstrat.geno
# snp2: /content/AdmixTools-master/bin/Genome_eigenstrat.snp
# ind2: /content/AdmixTools-master/bin/Genome_eigenstrat.ind
#
# genooutfilename: /content/AdmixTools-master/bin/Yusup_merged_with_1240K.geno
# snpoutfilename: /content/AdmixTools-master/bin/Yusup_merged_with_1240K.snp
# indoutfilename: /content/AdmixTools-master/bin/Yusup_merged_with_1240K.ind
#
# outputformat: EIGENSTRAT
# ```````````

# %%
# !ls
# Out:
# convertf		genome.txt			 qpDstat
# convertf_param.par	getresult			 qpF4ratio
# dataset			grabpars			 qpff3base
# dof4			jackdiff			 qpfmv
# dof4a			kimf				 qpfstats
# dowtjack		LICENSE				 qpGraph
# expfit.sh		mergeit				 qpmix
# gcount			merge_param.par			 qpreroot
# Genome_eigenstrat.geno	mkpretty			 qpWave
# Genome_eigenstrat.ind	numlines			 rexpfit.r
# Genome_eigenstrat.snp	plink				 rolloff
# Genome_merged.bed	plink_linux_x86_64_20231211.zip  rolloffp
# Genome_merged.bim	prettify			 simpjack2
# Genome_merged.fam	qp3Pop				 toy.map
# Genome_merged_hh.bed	qp4diff				 toy.ped
# Genome_merged_hh.bim	qpAdm				 v54.1.p1_1240K_public.tar
# Genome_merged_hh.fam	qpBound				 wtjack.pl
# Genome_merged_hh.log	qpDpart				 xtractcol
# Genome_merged.log	qpdslow				 xtractcolv

# %%
import subprocess

# Define the path to the executable and the parameter file
executable_path = '/content/AdmixTools-master/bin/mergeit'
param_file_path = '/content/AdmixTools-master/bin/merge_param.par'

# Run the executable with the parameter file
result = subprocess.run([executable_path, '-p', param_file_path], capture_output=True, text=True)

# Print the output
print("Standard Output:\n", result.stdout)
print("Standard Error:\n", result.stderr)
# Out:
# Standard Output:
#  parameter file: /content/AdmixTools-master/bin/merge_param.par
# geno1: /content/AdmixTools-master/bin/dataset/v54.1.p1_1240K_public.geno
# snp1: /content/AdmixTools-master/bin/dataset/v54.1.p1_1240K_public.snp
# ind1: /content/AdmixTools-master/bin/dataset/v54.1.p1_1240K_public.ind
# geno2: /content/AdmixTools-master/bin/Genome_eigenstrat.geno
# snp2: /content/AdmixTools-master/bin/Genome_eigenstrat.snp
# ind2: /content/AdmixTools-master/bin/Genome_eigenstrat.ind
# genooutfilename: /content/AdmixTools-master/bin/Yusup_merged_with_1240K.geno
# snpoutfilename: /content/AdmixTools-master/bin/Yusup_merged_with_1240K.snp
# indoutfilename: /content/AdmixTools-master/bin/Yusup_merged_with_1240K.ind
# outputformat: EIGENSTRAT
# allele funny: rs3820011 C A X X
# allele funny: rs59243365 G A X X
# allele funny: rs2817168 A G X X
# allele funny: rs2651909 G A X X
# allele funny: rs10158583 G A X X
# allele funny: rs2500252 C T X X
# allele funny: rs4415513 C T X X
# allele funny: rs2493278 T C X X
# allele funny: rs947344 C T X X
# allele funny: rs12117836 G A X X
# allele funny: rs1175550 A G X X
# allele funny: rs4128222 C A X X
# allele funny: rs10915428 G T X X
# allele funny: rs12077262 C T X X
# allele funny: rs6688343 T C X X
# allele funny: rs10799228 G A X X
# allele funny: rs537761 C A X X
# allele funny: rs242056 G A X X
# allele funny: rs2181699 G T X X
# allele funny: rs942245 A G X X
# allele funny: rs9439507 A G X X
# allele funny: rs2273042 G A X X
# allele funny: rs149094445 C T X X
# allele funny: rs140193828 G A X X
# allele funny: rs115030111 G A X X
# allele funny: rs4908610 C A X X
# allele funny: rs2412148 T C X X
# allele funny: rs2301488 C T X X
# allele funny: rs228642 C T X X
# allele funny: rs161803 A G X X
# allele funny: rs35675666 G T X X
# allele funny: rs9434652 C T X X
# allele funny: rs17032907 C T X X
# allele funny: rs10864390 C T X X
# allele funny: rs4406655 G A X X
# allele funny: rs9434723 G A X X
# allele funny: rs10746492 C T X X
# allele funny: rs2278611 G A X X
# allele funny: rs11121615 C T X X
# allele funny: rs6540951 G A X X
# allele funny: rs1281018 G A X X
# allele funny: rs2273348 A G X X
# allele funny: rs12121344 C T X X
# allele funny: rs2379159 C T X X
# allele funny: rs12134663 A C X X
# allele funny: rs1801133 G A X X
# allele funny: rs12562952 T C X X
# allele funny: rs1061631 G A X X
# allele funny: rs7546779 C T X X
# allele funny: rs760943 T C X X
# allele funny: rs3856278 A G X X
# allele funny: rs1262460 A G X X
# allele funny: rs7515525 G T X X
# allele funny: rs12408369 G A X X
# allele funny: rs4662010 C T X X
# allele funny: rs1203698 G A X X
# allele funny: rs12745720 C T X X
# allele funny: rs12758112 G A X X
# allele funny: rs3897492 A G X X
# allele funny: rs10927460 A G X X
# allele funny: rs10803288 C A X X
# allele funny: rs7681 G A X X
# allele funny: rs4661617 C T X X
# allele funny: rs10927764 C T X X
# allele funny: rs3766160 G A X X
# allele funny: rs11576404 G A X X
# allele funny: rs11260745 T C X X
# allele funny: rs6656611 T C X X
# allele funny: rs4661747 G A X X
# allele funny: rs10788679 A G X X
# allele funny: rs491778 T C X X
# allele funny: rs12026295 G A X X
# allele funny: rs6673711 T C X X
# allele funny: rs10158092 C A X X
# allele funny: rs74436986 C T X X
# allele funny: rs7530853 C T X X
# allele funny: rs10916852 G T X X
# allele funny: rs1110240 C T X X
# allele funny: rs10916958 T C X X
# allele funny: rs12124283 C T X X
# allele funny: rs1256279 C T X X
# allele funny: rs12759525 C T X X
# allele funny: rs10799746 A C X X
# allele funny: rs7543680 G A X X
# allele funny: rs17433222 G A X X
# allele funny: rs6687094 G A X X
# allele funny: rs2811946 A C X X
# allele funny: rs2864098 A G X X
# allele funny: rs4649203 G A X X
# allele funny: rs12064694 G A X X
# allele funny: rs4649002 G A X X
# allele funny: rs2885174 A C X X
# allele funny: rs3131513 G A X X
# allele funny: rs4568778 C T X X
# allele funny: rs11247870 C A X X
# allele funny: rs10751735 C T X X
# allele funny: rs7512595 A G X X
# allele funny: rs2808422 G T X X
# allele funny: rs3766400 A G X X
# allele funny: rs10902684 C T X X
# allele funny: rs3753864 T C X X
# allele funny: rs1042114 G T X X
# allele funny: rs12045777 C T X X
# allele funny: rs12401971 C T X X
# allele funny: rs10799128 T C X X
# allele funny: rs446335 G A X X
# allele funny: rs271344 G A X X
# allele funny: rs16832876 G A X X
# allele funny: rs10914556 C T X X
# allele funny: rs12027950 A G X X
# allele funny: rs4381243 A G X X
# allele funny: rs61768463 A G X X
# allele funny: rs647831 A G X X
# allele funny: rs9661612 G A X X
# allele funny: rs10914420 G A X X
# allele funny: rs6678903 T C X X
# allele funny: rs1566230 T C X X
# allele funny: rs544991 C T X X
# allele funny: rs4652973 C T X X
# allele funny: rs6425861 G A X X
# allele funny: rs502199 G A X X
# allele funny: rs12048816 T C X X
# allele funny: rs771124 T C X X
# allele funny: rs10799047 A C X X
# allele funny: rs615315 G T X X
# allele funny: rs491603 T C X X
# allele funny: rs11804163 C T X X
# allele funny: rs12409675 T C X X
# allele funny: rs477968 G A X X
# allele funny: rs532925 T C X X
# allele funny: rs640665 C T X X
# allele funny: rs10908340 G A X X
# allele funny: rs16824043 G A X X
# allele funny: rs4428850 G T X X
# allele funny: rs2480697 T G X X
# allele funny: rs1329967 A G X X
# allele funny: rs679143 A G X X
# allele funny: rs4660652 A G X X
# allele funny: rs10888609 C T X X
# allele funny: rs7538300 C A X X
# allele funny: rs6703320 C T X X
# allele funny: rs12120460 T C X X
# allele funny: rs230284 G A X X
# allele funny: rs11589250 G A X X
# allele funny: rs209618 A G X X
# allele funny: rs7537003 G A X X
# allele funny: rs618144 A G X X
# allele funny: rs12562229 A G X X
# allele funny: rs11208830 G A X X
# allele funny: rs12133860 C T X X
# allele funny: rs4132440 G A X X
# allele funny: rs10889959 T C X X
# allele funny: rs12718439 C T X X
# allele funny: rs510157 T G X X
# allele funny: rs1467809 G A X X
# allele funny: rs2485653 G A X X
# allele funny: rs11590549 C T X X
# allele funny: rs6671527 G A X X
# allele funny: rs669647 A G X X
# allele funny: rs9332998 T C X X
# allele funny: rs3737772 T C X X
# allele funny: rs543640 T G X X
# allele funny: rs11582540 C A X X
# allele funny: rs10890496 C T X X
# allele funny: rs638965 T C X X
# allele funny: rs1484412 G A X X
# allele funny: rs11205801 G T X X
# allele funny: rs11205949 T G X X
# allele funny: rs269324 C T X X
# allele funny: rs1242330 T G X X
# allele funny: rs1288386 G A X X
# allele funny: rs2297824 G A X X
# allele funny: rs12031794 C T X X
# allele funny: rs11579257 C T X X
# allele funny: rs612368 G A X X
# allele funny: rs4926684 G A X X
# allele funny: rs6588562 G A X X
# allele funny: rs11206887 G A X X
# allele funny: rs9803840 G T X X
# allele funny: rs1917339 A G X X
# allele funny: rs6687355 C T X X
# allele funny: rs7528953 T G X X
# allele funny: rs985782 T C X X
# allele funny: rs555213 A G X X
# allele funny: rs11583201 G A X X
# allele funny: rs942124 G A X X
# allele funny: rs12133457 G A X X
# allele funny: rs6683082 A G X X
# allele funny: rs114905259 G A X X
# allele funny: rs10443220 C T X X
# allele funny: rs17120548 G A X X
# allele funny: rs6701075 C T X X
# allele funny: rs2806440 A G X X
# allele funny: rs766488 G A X X
# allele funny: rs1125777 C T X X
# allele funny: rs7545732 G T X X
# allele funny: rs2365263 G A X X
# allele funny: rs12408292 C T X X
# allele funny: rs6685516 T C X X
# allele funny: rs6697273 T G X X
# allele funny: rs2365987 G A X X
# allele funny: rs12116810 T G X X
# allele funny: rs2457829 G A X X
# allele funny: rs7542665 T C X X
# allele funny: rs6683592 A G X X
# allele funny: rs11207944 C T X X
# allele funny: rs4915606 A G X X
# allele funny: rs1168029 G A X X
# allele funny: rs11207995 A C X X
# allele funny: rs2031373 C A X X
# allele funny: rs10889353 A C X X
# allele funny: rs11208012 T G X X
# allele funny: rs7522426 G A X X
# allele funny: rs968811 A G X X
# allele funny: rs2273122 T C X X
# allele funny: rs1260773 G A X X
# allele funny: rs834343 C A X X
# allele funny: rs10493358 A G X X
# allele funny: rs7517824 C T X X
# allele funny: rs7552434 G A X X
# allele funny: rs11208527 G A X X
# allele funny: rs576563 C T X X
# allele funny: rs2025804 G A X X
# allele funny: rs2025803 A G X X
# allele funny: rs1751492 C T X X
# allele funny: rs1137101 A G X X
# allele funny: rs4606347 G A X X
# allele funny: rs11812068 C A X X
# allele funny: rs1937457 C T X X
# allele funny: rs12040042 A G X X
# allele funny: rs11589862 C A X X
# allele funny: rs4393126 G A X X
# allele funny: rs11208886 G A X X
# allele funny: rs5008753 A G X X
# allele funny: rs17495916 T C X X
# allele funny: rs1925407 C T X X
# allele funny: rs17497947 G T X X
# allele funny: rs6693831 T C X X
# allele funny: rs12027122 A G X X
# allele funny: rs11209099 G A X X
# allele funny: rs557986 T C X X
# allele funny: rs12040310 G A X X
# allele funny: rs12046920 T G X X
# allele funny: rs2052959 T G X X
# allele funny: rs12407028 T C X X
# allele funny: rs10493436 C A X X
# allele funny: rs4926354 T C X X
# allele funny: rs9436812 T C X X
# allele funny: rs7527841 T G X X
# allele funny: rs12756859 C T X X
# allele funny: rs2420826 G A X X
# allele funny: rs868402 G T X X
# allele funny: rs11209464 C T X X
# allele funny: rs1341771 A G X X
# allele funny: rs10889836 C T X X
# allele funny: rs7515290 A G X X
# allele funny: rs1913268 G A X X
# allele funny: rs2782763 T C X X
# allele funny: rs2152134 A G X X
# allele funny: rs7523542 C A X X
# allele funny: rs11810467 T C X X
# allele funny: rs959 T C X X
# allele funny: rs1517754 C T X X
# allele funny: rs7550923 G A X X
# allele funny: rs10889924 C A X X
# allele funny: rs6661979 C T X X
# allele funny: rs12567329 A G X X
# allele funny: rs12039861 C A X X
# allele funny: rs2821267 G A X X
# allele funny: rs12026323 T G X X
# allele funny: rs1993709 A G X X
# allele funny: rs12140865 A C X X
# allele funny: rs10890042 G T X X
# allele funny: rs1454610 A G X X
# allele funny: rs1340440 G A X X
# allele funny: rs6672527 C T X X
# allele funny: rs3845348 G A X X
# allele funny: rs6593547 G T X X
# allele funny: rs1405308 T C X X
# allele funny: rs1857353 C T X X
# allele funny: rs11163461 A C X X
# allele funny: rs6662665 T C X X
# allele funny: rs5745325 G A X X
# allele funny: rs1251484 T C X X
# allele funny: rs1251578 C T X X
# allele funny: rs6681765 G A X X
# allele funny: rs410076 G A X X
# allele funny: rs172714 T C X X
# allele funny: rs341016 G A X X
# allele funny: rs962668 T C X X
# allele funny: rs6683950 C T X X
# allele funny: rs1498404 A G X X
# allele funny: rs10873941 G A X X
# allele funny: rs17381664 T C X X
# allele funny: rs1166588 C T X X
# allele funny: rs1166698 G A X X
# allele funny: rs1412414 A G X X
# allele funny: rs1475736 C T X X
# allele funny: rs4650608 T C X X
# allele funny: rs1937019 T C X X
# allele funny: rs1968956 G T X X
# allele funny: rs2065486 G A X X
# allele funny: rs1332819 C T X X
# allele funny: rs10489655 C A X X
# allele funny: rs6666584 G A X X
# allele funny: rs11162785 T G X X
# allele funny: rs11162883 C A X X
# allele funny: rs12140474 C T X X
# allele funny: rs4330881 G A X X
# allele funny: rs17105114 A G X X
# allele funny: rs12120655 G T X X
# allele funny: rs10874175 T C X X
# allele funny: rs10874177 T C X X
# allele funny: rs4650355 C T X X
# allele funny: rs11163182 T C X X
# allele funny: rs76532145 T C X X
# allele funny: rs1195685 A G X X
# allele funny: rs9662349 G A X X
# allele funny: rs638113 A G X X
# allele funny: rs11163396 C T X X
# allele funny: rs7523716 G T X X
# allele funny: rs1281404 G A X X
# allele funny: rs11163557 C T X X
# allele funny: rs17506077 T C X X
# allele funny: rs17109273 A G X X
# allele funny: rs10874349 T C X X
# allele funny: rs2184006 C T X X
# allele funny: rs4907144 A G X X
# allele funny: rs4243779 C T X X
# allele funny: rs2179763 A G X X
# allele funny: rs2812452 G A X X
# allele funny: rs7524898 C T X X
# allele funny: rs959363 A C X X
# allele funny: rs2945145 A C X X
# allele funny: rs10782528 A G X X
# allele funny: rs634294 A G X X
# allele funny: rs817482 T C X X
# allele funny: rs11161543 G A X X
# allele funny: rs233051 G A X X
# allele funny: rs366187 G A X X
# allele funny: rs6665006 T C X X
# allele funny: rs7546158 C T X X
# allele funny: rs1407719 A G X X
# allele funny: rs1886632 C T X X
# allele funny: rs11161943 T C X X
# allele funny: rs11161944 T C X X
# allele funny: rs4556331 C A X X
# allele funny: rs17129984 G A X X
# allele funny: rs10873855 A G X X
# allele funny: rs6694037 T C X X
# allele funny: rs12755168 T G X X
# allele funny: rs306317 C T X X
# allele funny: rs10922501 T C X X
# allele funny: rs12095496 C T X X
# allele funny: rs6688076 A G X X
# allele funny: rs10801783 A C X X
# allele funny: rs1329644 T C X X
# allele funny: rs6428576 G A X X
# allele funny: rs4388690 A C X X
# allele funny: rs527402 G A X X
# allele funny: rs469772 C T X X
# allele funny: rs12059556 C T X X
# allele funny: rs34856868 G A X X
# allele funny: rs12745968 A G X X
# allele funny: rs492054 C A X X
# allele funny: rs1678778 G A X X
# allele funny: rs2249590 G T X X
# allele funny: rs17109997 A G X X
# allele funny: rs11165058 G T X X
# allele funny: rs4847286 G T X X
# allele funny: rs12758064 T G X X
# allele funny: rs12743267 C T X X
# allele funny: rs589482 G A X X
# allele funny: rs326677 C T X X
# allele funny: rs12132152 G A X X
# allele funny: rs291593 G A X X
# allele funny: rs10493890 C T X X
# allele funny: rs6692946 A G X X
# allele funny: rs17376848 A G X X
# allele funny: rs13375516 A C X X
# allele funny: rs9662365 C T X X
# allele funny: rs11165976 C T X X
# allele funny: rs984271 G T X X
# allele funny: rs1329467 A G X X
# allele funny: rs12083740 T G X X
# allele funny: rs712889 C T X X
# allele funny: rs6695717 G T X X
# allele funny: rs620281 A G X X
# allele funny: rs3783621 C A X X
# allele funny: rs870747 T C X X
# allele funny: rs4341378 G A X X
# allele funny: rs9433784 G T X X
# allele funny: rs1199561 G A X X
# allele funny: rs12743305 G T X X
# allele funny: rs11164273 C T X X
# allele funny: rs11800637 C A X X
# allele funny: rs1938344 A C X X
# allele funny: rs11164621 C T X X
# allele funny: rs3753841 G A X X
# allele funny: rs12034300 A C X X
# allele funny: rs12035919 T C X X
# allele funny: rs7532749 T G X X
# allele funny: rs6676838 T C X X
# allele funny: rs4272631 G A X X
# allele funny: rs5000688 T C X X
# allele funny: rs6583061 G T X X
# allele funny: rs11184726 G T X X
# allele funny: rs6662285 G A X X
# allele funny: rs7529169 A G X X
# allele funny: rs640554 G A X X
# allele funny: rs11185131 A G X X
# allele funny: rs2494070 A G X X
# allele funny: rs1566254 T G X X
# allele funny: rs550743 T C X X
# allele funny: rs839878 A C X X
# allele funny: rs12239846 A G X X
# allele funny: rs7483 C T X X
# allele funny: rs10494112 A G X X
# allele funny: rs390923 A G X X
# allele funny: rs2484684 C T X X
# allele funny: rs814318 T C X X
# allele funny: rs724032 G A X X
# allele funny: rs12033004 A G X X
# allele funny: rs12075033 G A X X
# allele funny: rs6537742 C A X X
# allele funny: rs12069113 C T X X
# allele funny: rs4534375 T C X X
# allele funny: rs2996294 C A X X
# allele funny: rs1766884 T C X X
# allele funny: rs7552539 A G X X
# allele funny: rs1995483 G A X X
# allele funny: rs7520320 C T X X
# allele funny: rs1119040 G A X X
# allele funny: rs6680637 C T X X
# allele funny: rs1146165 G A X X
# allele funny: rs116067402 G A X X
# allele funny: rs11102929 G A X X
# allele funny: rs553146 C T X X
# allele funny: rs4046190 C T X X
# allele funny: rs1182221 G A X X
# allele funny: rs17235766 G A X X
# allele funny: rs12025144 A G X X
# allele funny: rs1146291 C T X X
# allele funny: rs1290600 T G X X
# allele funny: rs12031638 T G X X
# allele funny: rs319464 A G X X
# allele funny: rs12058607 C T X X
# allele funny: rs12124243 T C X X
# allele funny: rs2798449 G A X X
# allele funny: rs1213884 A C X X
# allele funny: rs911244 C T X X
# allele funny: rs1923025 A G X X
# allele funny: rs481357 T C X X
# allele funny: rs2582783 T C X X
# allele funny: rs17024584 G A X X
# allele funny: rs4950437 A C X X
# allele funny: rs10900376 A G X X
# allele funny: rs12402939 A C X X
# allele funny: rs3748545 G A X X
# allele funny: rs7007 T C X X
# allele funny: rs6587673 G A X X
# allele funny: rs6659798 T C X X
# allele funny: rs4845491 T C X X
# allele funny: rs4363385 T C X X
# allele funny: rs56934782 G A X X
# allele funny: rs11264446 C T X X
# allele funny: rs7514452 C T X X
# allele funny: rs7543897 C T X X
# allele funny: rs6426905 T C X X
# allele funny: rs1218578 A G X X
# allele funny: rs4845406 A G X X
# allele funny: rs11264341 C T X X
# allele funny: rs1052067 G A X X
# allele funny: rs752640 G A X X
# allele funny: rs16837408 C T X X
# allele funny: rs2644590 C A X X
# allele funny: rs10494309 T C X X
# allele funny: rs6656933 G T X X
# allele funny: rs1000073 A G X X
# allele funny: rs7544297 A C X X
# allele funny: rs2209354 T C X X
# allele funny: rs2224902 C T X X
# allele funny: rs692565 T C X X
# allele funny: rs691314 G A X X
# allele funny: rs857847 G A X X
# allele funny: rs16841134 T C X X
# allele funny: rs4657618 T C X X
# allele funny: rs10489846 A G X X
# allele funny: rs2814774 T C X X
# allele funny: rs2852714 A G X X
# allele funny: rs12075 G A X X
# allele funny: rs12072644 C T X X
# allele funny: rs4656784 A G X X
# allele funny: rs35393723 G A X X
# allele funny: rs10494326 C T X X
# allele funny: rs11265381 G T X X
# allele funny: rs4073054 C A X X
# allele funny: rs4657039 A G X X
# allele funny: rs1538971 T C X X
# allele funny: rs1047802 G T X X
# allele funny: rs17431968 G A X X
# allele funny: rs12047510 T C X X
# allele funny: rs10917696 T C X X
# allele funny: rs11802875 C T X X
# allele funny: rs1396544 G A X X
# allele funny: rs2486824 G A X X
# allele funny: rs10799928 C T X X
# allele funny: rs4657329 C A X X
# allele funny: rs11800877 C A X X
# allele funny: rs1213285 A G X X
# allele funny: rs6426912 T C X X
# allele funny: rs4657451 G A X X
# allele funny: rs3845536 C T X X
# allele funny: rs10918428 A G X X
# allele funny: rs12097144 T C X X
# allele funny: rs539482 G A X X
# allele funny: rs869714 C T X X
# allele funny: rs10918695 C T X X
# allele funny: rs2794984 T G X X
# allele funny: rs1229355 A G X X
# allele funny: rs3753931 C T X X
# allele funny: rs203849 A G X X
# allele funny: rs2179184 A G X X
# allele funny: rs858099 A C X X
# allele funny: rs75182344 G A X X
# allele funny: rs16861990 A C X X
# allele funny: rs6028 T C X X
# allele funny: rs9803860 A G X X
# allele funny: rs2272920 G T X X
# allele funny: rs986032 A G X X
# allele funny: rs7881161 C T X X
# allele funny: rs1736565 C T X X
# allele funny: rs13376631 A G X X
# allele funny: rs7877 C T X X
# allele funny: rs1342032 A C X X
# allele funny: rs6685520 G A X X
# allele funny: rs78495657 C T X X
# allele funny: rs6696455 T C X X
# allele funny: rs12732088 A G X X
# allele funny: rs859433 G A X X
# allele funny: rs35266764 T C X X
# allele funny: rs2179158 T C X X
# allele funny: rs2455730 A G X X
# allele funny: rs909941 A G X X
# allele funny: rs932311 G T X X
# allele funny: rs1885646 A G X X
# allele funny: rs4442331 G A X X
# allele funny: rs12065872 G T X X
# allele funny: rs4650993 A G X X
# allele funny: rs12085081 A C X X
# allele funny: rs16853281 G A X X
# allele funny: rs6672395 T C X X
# allele funny: rs4259605 A C X X
# allele funny: rs10797667 T C X X
# allele funny: rs9803794 A G X X
# allele funny: rs6696547 T C X X
# allele funny: rs12564594 A G X X
# allele funny: rs2246119 G T X X
# allele funny: rs2256956 G A X X
# allele funny: rs61548814 C T X X
# allele funny: rs7554927 G T X X
# allele funny: rs7533385 A G X X
# allele funny: rs10911193 C T X X
# allele funny: rs2378788 A G X X
# allele funny: rs12096645 C T X X
# allele funny: rs756199 A G X X
# allele funny: rs16822379 T C X X
# allele funny: rs114231218 T C X X
# allele funny: rs932993 C T X X
# allele funny: rs10911612 G A X X
# allele funny: rs10911628 C A X X
# allele funny: rs10798019 A C X X
# allele funny: rs10127540 T C X X
# allele funny: rs7556537 A C X X
# allele funny: rs12078444 T C X X
# allele funny: rs10494587 G A X X
# allele funny: rs5275 A G X X
# allele funny: rs12143166 A G X X
# allele funny: rs12726519 C T X X
# allele funny: rs11800915 G T X X
# allele funny: rs776797 G A X X
# allele funny: rs10798156 C A X X
# allele funny: rs354255 C T X X
# allele funny: rs10737562 A G X X
# allele funny: rs12138327 C T X X
# allele funny: rs11801703 C T X X
# allele funny: rs950569 G T X X
# allele funny: rs10920093 C A X X
# allele funny: rs12065497 G A X X
# allele funny: rs7541423 C T X X
# allele funny: rs10494649 T C X X
# allele funny: rs11811680 T C X X
# allele funny: rs11800005 A G X X
# allele funny: rs10494658 T G X X
# allele funny: rs6690126 T C X X
# allele funny: rs12085373 C T X X
# allele funny: rs2131384 T G X X
# allele funny: rs764552 A G X X
# allele funny: rs10494714 T C X X
# allele funny: rs1934206 A C X X
# allele funny: rs16838214 T C X X
# allele funny: rs10754139 A G X X
# allele funny: rs12063569 A G X X
# allele funny: rs7546529 A G X X
# allele funny: rs12029379 C A X X
# allele funny: rs12145838 T G X X
# allele funny: rs12405380 A G X X
# allele funny: rs1329424 T G X X
# allele funny: rs1061170 C T X X
# allele funny: rs2270763 T C X X
# allele funny: rs1233833 G A X X
# allele funny: rs7529161 A G X X
# allele funny: rs16842754 C A X X
# allele funny: rs6428467 A C X X
# allele funny: rs16843434 A G X X
# allele funny: rs6673408 G A X X
# allele funny: rs6701884 A G X X
# allele funny: rs7529925 C T X X
# allele funny: rs6667273 C A X X
# allele funny: rs12354285 C A X X
# allele funny: rs2812261 T G X X
# allele funny: rs7521914 T C X X
# allele funny: rs2292096 A G X X
# allele funny: rs12564878 A G X X
# allele funny: rs296543 T C X X
# allele funny: rs3752978 A G X X
# allele funny: rs7551098 C T X X
# allele funny: rs967392 C A X X
# allele funny: rs6689634 C T X X
# allele funny: rs12756809 A C X X
# allele funny: rs3010069 G A X X
# allele funny: rs4072661 C T X X
# allele funny: rs3924585 G A X X
# allele funny: rs1877394 G A X X
# allele funny: rs3827534 C T X X
# allele funny: rs3789044 G A X X
# allele funny: rs11801229 A G X X
# allele funny: rs11803913 G A X X
# allele funny: rs11240309 A G X X
# allele funny: rs3892248 G A X X
# allele funny: rs2802809 C T X X
# allele funny: rs17417252 A G X X
# allele funny: rs4623769 G A X X
# allele funny: rs12565564 A G X X
# allele funny: rs74145068 A C X X
# allele funny: rs28619955 A G X X
# allele funny: rs10863389 C T X X
# allele funny: rs6690037 A G X X
# allele funny: rs1367068 A G X X
# allele funny: rs2940252 C A X X
# allele funny: rs12034598 A G X X
# allele funny: rs12034383 G A X X
# allele funny: rs11118516 G A X X
# allele funny: rs2796254 G A X X
# allele funny: rs652727 C T X X
# allele funny: rs7540179 A G X X
# allele funny: rs4844419 A G X X
# allele funny: rs1539168 G A X X
# allele funny: rs12091708 G A X X
# allele funny: rs11119169 C T X X
# allele funny: rs4844477 C T X X
# allele funny: rs685532 T C X X
# allele funny: rs12067861 C T X X
# allele funny: rs926578 C T X X
# allele funny: rs1890843 T C X X
# allele funny: rs17017032 G A X X
# allele funny: rs6540679 A G X X
# allele funny: rs2292483 G A X X
# allele funny: rs2165993 A G X X
# allele funny: rs10158205 C T X X
# allele funny: rs6690208 C T X X
# allele funny: rs11809969 A G X X
# allele funny: rs10863957 T C X X
# allele funny: rs2137424 T C X X
# allele funny: rs3795837 A C X X
# allele funny: rs2492788 T C X X
# allele funny: rs2501847 C T X X
# allele funny: rs2221593 C T X X
# allele funny: rs11542154 G A X X
# allele funny: rs6697921 C T X X
# allele funny: rs1656014 A G X X
# allele funny: rs320471 A G X X
# allele funny: rs4655466 A G X X
# allele funny: rs3013445 G A X X
# allele funny: rs12563432 G A X X
# allele funny: rs11120596 C T X X
# allele funny: rs2820716 T C X X
# allele funny: rs4308955 C A X X
# allele funny: rs6540916 C T X X
# allele funny: rs6702277 C T X X
# allele funny: rs10492958 T C X X
# allele funny: rs3000609 G A X X
# allele funny: rs1339222 G A X X
# allele funny: rs7539648 G A X X
# allele funny: rs1910147 T C X X
# allele funny: rs12749938 C T X X
# allele funny: rs1567449 C T X X
# allele funny: rs10863373 G T X X
# allele funny: rs991967 A C X X
# allele funny: rs637991 T C X X
# allele funny: rs12123734 G A X X
# allele funny: rs2605100 A G X X
# allele funny: rs2785979 T C X X
# allele funny: rs11118346 C T X X
# allele funny: rs7514869 A G X X
# allele funny: rs11805285 C T X X
# allele funny: rs12402198 G A X X
# allele funny: rs12408093 C T X X
# allele funny: rs12073837 C T X X
# allele funny: rs11581623 C T X X
# allele funny: rs4240927 C T X X
# allele funny: rs6691170 G T X X
# allele funny: rs2800846 T C X X
# allele funny: rs1772283 T C X X
# allele funny: rs868966 G A X X
# allele funny: rs10915896 C T X X
# allele funny: rs61835429 G A X X
# allele funny: rs10916019 G A X X
# allele funny: rs708766 A C X X
# allele funny: rs2077734 G T X X
# allele funny: rs2802270 G A X X
# allele funny: rs2236358 G A X X
# allele funny: rs115476782 C A X X
# allele funny: rs6692721 G A X X
# allele funny: rs1870362 G A X X
# allele funny: rs7538164 G A X X
# allele funny: rs12117146 A G X X
# allele funny: rs613961 T C X X
# allele funny: rs2296065 G A X X
# allele funny: rs4846922 T C X X
# allele funny: rs853431 A G X X
# allele funny: rs853469 T C X X
# allele funny: rs2493151 G A X X
# allele funny: rs6541239 A G X X
# allele funny: rs4658931 G T X X
# allele funny: rs2180273 T C X X
# allele funny: rs2486736 C T X X
# allele funny: rs2812385 G T X X
# allele funny: rs11122362 C T X X
# allele funny: rs9308484 A G X X
# allele funny: rs1331046 C A X X
# allele funny: rs78309810 C T X X
# allele funny: rs1547742 G A X X
# allele funny: rs789643 G A X X
# allele funny: rs11804919 A G X X
# allele funny: rs10752798 C A X X
# allele funny: rs2477858 A G X X
# allele funny: rs6687497 T C X X
# allele funny: rs2477863 G T X X
# allele funny: rs12036063 T C X X
# allele funny: rs2145790 G A X X
# allele funny: rs12132550 C T X X
# allele funny: rs7539909 T C X X
# allele funny: rs780214 C T X X
# allele funny: rs1083873 C T X X
# allele funny: rs7542878 C A X X
# allele funny: rs4442431 C T X X
# allele funny: rs4333882 A G X X
# allele funny: rs535513 A G X X
# allele funny: rs501664 A G X X
# allele funny: rs3951276 G A X X
# allele funny: rs10797553 A G X X
# allele funny: rs4660126 A G X X
# allele funny: rs16833075 T G X X
# allele funny: rs927730 C T X X
# allele funny: rs10925151 G A X X
# allele funny: rs597220 T G X X
# allele funny: rs1805087 A G X X
# allele funny: rs4638118 G A X X
# allele funny: rs7529251 C T X X
# allele funny: rs1418208 A G X X
# allele funny: rs2841417 G A X X
# allele funny: rs9428818 T C X X
# allele funny: rs1858175 A G X X
# allele funny: rs7529084 T C X X
# allele funny: rs10495457 A G X X
# allele funny: rs6660298 C T X X
# allele funny: rs6699880 G A X X
# allele funny: rs10926222 C T X X
# allele funny: rs12130718 G A X X
# allele funny: rs10802866 C T X X
# allele funny: rs12064827 C T X X
# allele funny: rs3828024 G A X X
# allele funny: rs10802910 G A X X
# allele funny: rs10926392 T C X X
# allele funny: rs1544190 C T X X
# allele funny: rs6678766 A G X X
# allele funny: rs28407556 A G X X
# allele funny: rs11809951 A G X X
# allele funny: rs12060035 C T X X
# allele funny: rs4430311 C T X X
# allele funny: rs10803168 G A X X
# allele funny: rs12076800 T C X X
# allele funny: rs7520160 C T X X
# allele funny: rs4658627 G A X X
# allele funny: rs12087973 C T X X
# allele funny: rs10927306 G A X X
# allele funny: rs10803251 A G X X
# allele funny: rs4658446 G A X X
# allele funny: rs6428914 C A X X
# allele funny: rs1715789 A G X X
# allele funny: rs3820246 G A X X
# allele funny: rs1934574 G T X X
# allele funny: rs9660719 C T X X
# allele funny: rs7547858 T C X X
# allele funny: rs4654291 C T X X
# allele funny: rs10924849 C A X X
# allele funny: rs2255481 C T X X
# allele funny: rs3862182 T C X X
# allele funny: rs10888379 T C X X
# allele funny: rs7530535 G A X X
# allele funny: rs10888287 T G X X
# allele funny: rs6587472 C T X X
# allele funny: rs11205415 T G X X
# allele funny: rs7605824 G A X X
# allele funny: rs2724855 G A X X
# allele funny: rs2724882 G A X X
# allele funny: rs17784455 C T X X
# allele funny: rs1126799 T C X X
# allele funny: rs11888121 G A X X
# allele funny: rs1978703 C T X X
# allele funny: rs7596980 C T X X
# allele funny: rs2668827 T C X X
# allele funny: rs11694900 C T X X
# allele funny: rs896223 T G X X
# allele funny: rs896234 C T X X
# allele funny: rs733879 A G X X
# allele funny: rs730344 C T X X
# allele funny: rs7592135 G A X X
# allele funny: rs7595702 C A X X
# allele funny: rs34276084 C T X X
# allele funny: rs4546035 C T X X
# allele funny: rs13017757 C T X X
# allele funny: rs7563964 A C X X
# allele funny: rs4850000 T C X X
# allele funny: rs2118380 C A X X
# allele funny: rs6716364 C T X X
# allele funny: rs2121221 C T X X
# allele funny: rs699549 T C X X
# allele funny: rs13403240 A G X X
# allele funny: rs12692340 G A X X
# allele funny: rs6720039 G A X X
# allele funny: rs792088 C T X X
# allele funny: rs1370937 G A X X
# allele funny: rs16864493 A G X X
# allele funny: rs11685714 A G X X
# allele funny: rs1816975 C T X X
# allele funny: rs3101047 C T X X
# allele funny: rs12619231 C T X X
# allele funny: rs6734387 T C X X
# allele funny: rs812811 A G X X
# allele funny: rs11676467 C T X X
# allele funny: rs6745856 G T X X
# allele funny: rs6736951 G A X X
# allele funny: rs968763 G A X X
# allele funny: rs1364058 G A X X
# allele funny: rs7572976 C T X X
# allele funny: rs2630726 A G X X
# allele funny: rs10427278 G A X X
# allele funny: rs3927971 C T X X
# allele funny: rs11685635 C T X X
# allele funny: rs6431990 A G X X
# allele funny: rs6432025 C T X X
# allele funny: rs908295 G A X X
# allele funny: rs7420933 A G X X
# allele funny: rs9287724 C A X X
# allele funny: rs10178826 A C X X
# allele funny: rs7573335 T C X X
# allele funny: rs4669688 T C X X
# allele funny: rs75493128 C A X X
# allele funny: rs6718783 G T X X
# allele funny: rs12613478 C T X X
# allele funny: rs58152553 C T X X
# allele funny: rs2380426 C T X X
# allele funny: rs77374145 G A X X
# allele funny: rs4669845 G A X X
# allele funny: rs1818595 A G X X
# allele funny: rs12612960 C T X X
# allele funny: rs12617484 A G X X
# allele funny: rs9287763 T C X X
# allele funny: rs7579086 G A X X
# allele funny: rs17311650 A C X X
# allele funny: rs6744117 A G X X
# allele funny: rs10170192 C T X X
# allele funny: rs2049681 T C X X
# allele funny: rs4668879 T C X X
# allele funny: rs7579979 A G X X
# allele funny: rs2380684 G A X X
# allele funny: rs116139222 G A X X
# allele funny: rs11685620 C T X X
# allele funny: rs62116688 T C X X
# allele funny: rs10183647 T C X X
# allele funny: rs13023785 T C X X
# allele funny: rs6723318 G T X X
# allele funny: rs11889338 G A X X
# allele funny: rs16983552 C T X X
# allele funny: rs1065381 C T X X
# allele funny: rs13008425 T G X X
# allele funny: rs2710005 G A X X
# allele funny: rs4119150 C T X X
# allele funny: rs7558413 G A X X
# allele funny: rs4129693 C T X X
# allele funny: rs1527485 C T X X
# allele funny: rs1377400 C T X X
# allele funny: rs10184446 A G X X
# allele funny: rs7563410 C A X X
# allele funny: rs10175486 C T X X
# allele funny: rs1191778 T C X X
# allele funny: rs28732678 G A X X
# allele funny: rs6709280 C T X X
# allele funny: rs9679195 T C X X
# allele funny: rs9085 A C X X
# allele funny: rs667529 T C X X
# allele funny: rs17721572 C T X X
# allele funny: rs312966 A G X X
# allele funny: rs312984 C T X X
# allele funny: rs1878512 C A X X
# allele funny: rs447986 T C X X
# allele funny: rs219549 T C X X
# allele funny: rs3922224 G A X X
# allele funny: rs6751535 G A X X
# allele funny: rs6726088 T G X X
# allele funny: rs7559638 C T X X
# allele funny: rs4143808 A G X X
# allele funny: rs1344753 T G X X
# allele funny: rs7588286 A G X X
# allele funny: rs2543662 C A X X
# allele funny: rs1541984 G A X X
# allele funny: rs4665736 C T X X
# allele funny: rs934778 A G X X
# allele funny: rs10180663 T C X X
# allele funny: rs11678268 T C X X
# allele funny: rs3856394 A G X X
# allele funny: rs7607198 A C X X
# allele funny: rs4665830 G A X X
# allele funny: rs6753473 T G X X
# allele funny: rs2052937 C T X X
# allele funny: rs7565734 T G X X
# allele funny: rs3795958 A G X X
# allele funny: rs10167513 G A X X
# allele funny: rs1148967 C A X X
# allele funny: rs11887277 T C X X
# allele funny: rs780093 T C X X
# allele funny: rs4665987 G A X X
# allele funny: rs11127145 A G X X
# allele funny: rs113849934 G A X X
# allele funny: rs6547857 A G X X
# allele funny: rs6741437 A G X X
# allele funny: rs11678098 A G X X
# allele funny: rs7586405 A G X X
# allele funny: rs4666151 C A X X
# allele funny: rs57005658 T G X X
# allele funny: rs7570135 G A X X
# allele funny: rs10178180 G A X X
# allele funny: rs60330717 T C X X
# allele funny: rs10445906 A G X X
# allele funny: rs7569431 G A X X
# allele funny: rs4381747 C A X X
# allele funny: rs7605273 G T X X
# allele funny: rs10201541 A G X X
# allele funny: rs142751729 G A X X
# allele funny: rs4434038 G A X X
# allele funny: rs829699 T C X X
# allele funny: rs7565755 T C X X
# allele funny: rs2123752 T C X X
# allele funny: rs4952192 C T X X
# allele funny: rs4951964 G A X X
# allele funny: rs420731 C A X X
# allele funny: rs9308929 A G X X
# allele funny: rs150719 A G X X
# allele funny: rs219178 A G X X
# allele funny: rs139567480 C T X X
# allele funny: rs2887087 T C X X
# allele funny: rs4670815 T C X X
# allele funny: rs4670300 G A X X
# allele funny: rs4309564 C T X X
# allele funny: rs4670331 G T X X
# allele funny: rs12622260 T C X X
# allele funny: rs17015496 C T X X
# allele funny: rs280749 G T X X
# allele funny: rs1026301 A C X X
# allele funny: rs12613713 A G X X
# allele funny: rs2719107 T C X X
# allele funny: rs11683407 T C X X
# allele funny: rs10170933 A G X X
# allele funny: rs13417436 C T X X
# allele funny: rs1167450 T C X X
# allele funny: rs7584784 C T X X
# allele funny: rs848514 A G X X
# allele funny: rs3770832 C A X X
# allele funny: rs10176047 T C X X
# allele funny: rs6708931 A G X X
# allele funny: rs10490284 T G X X
# allele funny: rs12615921 A G X X
# allele funny: rs1446296 T G X X
# allele funny: rs10174646 C A X X
# allele funny: rs372139 G A X X
# allele funny: rs9679549 T C X X
# allele funny: rs2192703 C T X X
# allele funny: rs13015010 C T X X
# allele funny: rs7586183 C T X X
# allele funny: rs4952441 G A X X
# allele funny: rs3851317 T C X X
# allele funny: rs10204821 A G X X
# allele funny: rs4500987 C T X X
# allele funny: rs729559 A G X X
# allele funny: rs2719150 T C X X
# allele funny: rs4453730 C A X X
# allele funny: rs10202624 A G X X
# allele funny: rs3816183 T C X X
# allele funny: rs2052927 G A X X
# allele funny: rs7601418 T C X X
# allele funny: rs4953030 A G X X
# allele funny: rs12622038 G T X X
# allele funny: rs895636 C T X X
# allele funny: rs6719695 T C X X
# allele funny: rs929902 G T X X
# allele funny: rs883413 T G X X
# allele funny: rs1862892 C T X X
# allele funny: rs2344662 A C X X
# allele funny: rs13404973 G A X X
# allele funny: rs6727698 T C X X
# allele funny: rs1000531 C T X X
# allele funny: rs12712973 A C X X
# allele funny: rs1376406 A G X X
# allele funny: rs2122715 A G X X
# allele funny: rs17769101 G A X X
# allele funny: rs6718957 C T X X
# allele funny: rs17774133 C T X X
# allele funny: rs7578781 G A X X
# allele funny: rs3924917 G A X X
# allele funny: rs10182660 T C X X
# allele funny: rs2969775 G T X X
# allele funny: rs797700 C T X X
# allele funny: rs6729916 T C X X
# allele funny: rs4430989 G A X X
# allele funny: rs7583082 A G X X
# allele funny: rs9309154 G T X X
# allele funny: rs6746533 T G X X
# allele funny: rs2556406 A G X X
# allele funny: rs7583216 G A X X
# allele funny: rs17038751 A G X X
# allele funny: rs10172488 G A X X
# allele funny: rs971732 A C X X
# allele funny: rs9636391 A G X X
# allele funny: rs17040210 C T X X
# allele funny: rs10048731 T C X X
# allele funny: rs10490174 G A X X
# allele funny: rs11884918 T C X X
# allele funny: rs2193417 C T X X
# allele funny: rs2353303 A G X X
# allele funny: rs17041599 G T X X
# allele funny: rs1528792 A G X X
# allele funny: rs2698028 C T X X
# allele funny: rs12478948 A G X X
# allele funny: rs10201204 T C X X
# allele funny: rs6712068 G A X X
# allele funny: rs11125414 C A X X
# allele funny: rs4971598 G T X X
# allele funny: rs4625951 T C X X
# allele funny: rs4672476 A G X X
# allele funny: rs2357013 C T X X
# allele funny: rs56264986 C T X X
# allele funny: rs2172645 A C X X
# allele funny: rs843748 G A X X
# allele funny: rs11680886 G A X X
# allele funny: rs13393949 G A X X
# allele funny: rs1510611 G T X X
# allele funny: rs7564091 G A X X
# allele funny: rs17046387 T G X X
# allele funny: rs12713280 C T X X
# allele funny: rs3198123 C T X X
# allele funny: rs2972076 A G X X
# allele funny: rs2972072 G T X X
# allele funny: rs12464796 C T X X
# allele funny: rs10189439 C A X X
# allele funny: rs782590 C T X X
# allele funny: rs6545528 C T X X
# allele funny: rs3791679 A G X X
# allele funny: rs2160706 T C X X
# allele funny: rs6715352 G A X X
# allele funny: rs4671301 A G X X
# allele funny: rs11125711 G A X X
# allele funny: rs13396309 T G X X
# allele funny: rs10204326 A G X X
# allele funny: rs820953 A G X X
# allele funny: rs7602685 G A X X
# allele funny: rs13026414 C T X X
# allele funny: rs13021589 A G X X
# allele funny: rs10490250 A C X X
# allele funny: rs72817933 C T X X
# allele funny: rs55645922 A C X X
# allele funny: rs12993019 C T X X
# allele funny: rs7588875 A G X X
# allele funny: rs13383367 A G X X
# allele funny: rs2041719 A G X X
# allele funny: rs6545742 T C X X
# allele funny: rs2192513 G T X X
# allele funny: rs6545747 C A X X
# allele funny: rs4671357 T C X X
# allele funny: rs1512226 A G X X
# allele funny: rs13408761 A G X X
# allele funny: rs243081 G A X X
# allele funny: rs7579240 G T X X
# allele funny: rs11678166 G A X X
# allele funny: rs4672416 C T X X
# allele funny: rs6735330 G A X X
# allele funny: rs4233975 G A X X
# allele funny: rs2421509 G A X X
# allele funny: rs7574498 A G X X
# allele funny: rs11681733 C T X X
# allele funny: rs13391261 G A X X
# allele funny: rs7591656 T C X X
# allele funny: rs10490211 C T X X
# allele funny: rs702942 G A X X
# allele funny: rs11891634 C A X X
# allele funny: rs2193467 G A X X
# allele funny: rs890094 T C X X
# allele funny: rs6546206 A G X X
# allele funny: rs7586464 G T X X
# allele funny: rs6748113 A C X X
# allele funny: rs2971848 C T X X
# allele funny: rs10490189 G T X X
# allele funny: rs4671792 G A X X
# allele funny: rs73936562 C T X X
# allele funny: rs11126167 C A X X
# allele funny: rs11902811 A G X X
# allele funny: rs6736893 T G X X
# allele funny: rs6735917 G A X X
# allele funny: rs4854519 G T X X
# allele funny: rs13388699 A G X X
# allele funny: rs1106518 G A X X
# allele funny: rs4435491 A C X X
# allele funny: rs4542888 A G X X
# allele funny: rs6710260 A G X X
# allele funny: rs10179227 A G X X
# allele funny: rs6546546 G T X X
# allele funny: rs17006519 C T X X
# allele funny: rs6734489 G A X X
# allele funny: rs115891065 C T X X
# allele funny: rs6713986 A C X X
# allele funny: rs12623780 C T X X
# allele funny: rs883313 C T X X
# allele funny: rs4852856 C T X X
# allele funny: rs10181341 G A X X
# allele funny: rs640610 C T X X
# allele funny: rs6710739 C T X X
# allele funny: rs6546824 G A X X
# allele funny: rs9309473 A G X X
# allele funny: rs13391552 G A X X
# allele funny: rs6546886 T C X X
# allele funny: rs1047911 C A X X
# allele funny: rs11688381 A G X X
# allele funny: rs4853100 A G X X
# allele funny: rs3771817 A G X X
# allele funny: rs741418 G A X X
# allele funny: rs3821316 T C X X
# allele funny: rs13017967 G A X X
# allele funny: rs6546993 C A X X
# allele funny: rs13390508 G A X X
# allele funny: rs11687001 C T X X
# allele funny: rs7580730 C T X X
# allele funny: rs1837426 C T X X
# allele funny: rs1030956 G A X X
# allele funny: rs17013773 C T X X
# allele funny: rs1505229 C T X X
# allele funny: rs17648731 C T X X
# allele funny: rs12052760 C A X X
# allele funny: rs1386382 A G X X
# allele funny: rs2035620 A G X X
# allele funny: rs4575747 C T X X
# allele funny: rs6751378 T C X X
# allele funny: rs6719192 T C X X
# allele funny: rs7571032 A G X X
# allele funny: rs10173591 C T X X
# allele funny: rs2839828 C A X X
# allele funny: rs7578411 T C X X
# allele funny: rs4853418 T C X X
# allele funny: rs1608234 T C X X
# allele funny: rs17016433 G A X X
# allele funny: rs10496216 A G X X
# allele funny: rs1996867 T C X X
# allele funny: rs1864549 C A X X
# allele funny: rs925404 T C X X
# allele funny: rs971476 T C X X
# allele funny: rs2861904 C T X X
# allele funny: rs2861914 T G X X
# allele funny: rs10172412 A G X X
# allele funny: rs2916491 T C X X
# allele funny: rs7597545 C T X X
# allele funny: rs80030097 A G X X
# allele funny: rs7561634 T G X X
# allele funny: rs10520291 G A X X
# allele funny: rs12476834 A G X X
# allele funny: rs7581118 C T X X
# allele funny: rs1347504 A C X X
# allele funny: rs10496265 T C X X
# allele funny: rs1344740 C T X X
# allele funny: rs13009422 G A X X
# allele funny: rs10496289 C T X X
# allele funny: rs6743753 C A X X
# allele funny: rs1896848 G T X X
# allele funny: rs2129392 A C X X
# allele funny: rs1918690 T C X X
# allele funny: rs955592 C T X X
# allele funny: rs1135604 C T X X
# allele funny: rs1877954 G A X X
# allele funny: rs11680227 A G X X
# allele funny: rs1130866 G A X X
# allele funny: rs17584578 G A X X
# allele funny: rs4432450 G A X X
# allele funny: rs2919851 A G X X
# allele funny: rs4972211 G A X X
# allele funny: rs1914687 G A X X
# allele funny: rs1724120 T C X X
# allele funny: rs7603256 C T X X
# allele funny: rs11901495 G A X X
# allele funny: rs11894651 C A X X
# allele funny: rs3769754 A C X X
# allele funny: rs12615689 G A X X
# allele funny: rs7583877 C T X X
# allele funny: rs4851365 C T X X
# allele funny: rs7577564 C T X X
# allele funny: rs13401717 G A X X
# allele funny: rs10199359 T C X X
# allele funny: rs933493 C T X X
# allele funny: rs1558648 T G X X
# allele funny: rs3771180 G T X X
# allele funny: rs13015714 G T X X
# allele funny: rs13018263 T C X X
# allele funny: rs13401789 G A X X
# allele funny: rs12105421 C T X X
# allele funny: rs17028232 T C X X
# allele funny: rs6709515 C T X X
# allele funny: rs4131749 G A X X
# allele funny: rs12613775 C T X X
# allele funny: rs11890236 T C X X
# allele funny: rs4851683 T C X X
# allele funny: rs72945511 G T X X
# allele funny: rs2679870 G A X X
# allele funny: rs12468349 C T X X
# allele funny: rs12473672 A G X X
# allele funny: rs1126240 A C X X
# allele funny: rs6712413 G A X X
# allele funny: rs7563743 A C X X
# allele funny: rs12995333 G T X X
# allele funny: rs1465639 T C X X
# allele funny: rs13432204 G A X X
# allele funny: rs1031716 G T X X
# allele funny: rs6753056 G T X X
# allele funny: rs6542736 G A X X
# allele funny: rs826682 A C X X
# allele funny: rs121908454 C T X X
# allele funny: rs17034806 A G X X
# allele funny: rs9653456 A C X X
# allele funny: rs10171167 A C X X
# allele funny: rs919943 G A X X
# allele funny: rs10178717 A G X X
# allele funny: rs10207392 A G X X
# allele funny: rs12469600 T C X X
# allele funny: rs3811047 A G X X
# allele funny: rs6743376 C A X X
# allele funny: rs1542176 C T X X
# allele funny: rs1053413 A G X X
# allele funny: rs2900745 G A X X
# allele funny: rs3748997 T C X X
# allele funny: rs12622591 A G X X
# allele funny: rs882575 T C X X
# allele funny: rs4459743 T C X X
# allele funny: rs4491738 T C X X
# allele funny: rs13425437 T G X X
# allele funny: rs4848430 C T X X
# allele funny: rs17046680 A G X X
# allele funny: rs4849559 T C X X
# allele funny: rs13390020 T C X X
# allele funny: rs1808458 C T X X
# allele funny: rs11888583 A C X X
# allele funny: rs13412685 C T X X
# allele funny: rs4491733 A G X X
# allele funny: rs4849770 G A X X
# allele funny: rs1545360 A G X X
# allele funny: rs6542524 T C X X
# allele funny: rs12472563 C T X X
# allele funny: rs13408457 C A X X
# allele funny: rs13009791 G A X X
# allele funny: rs707482 C T X X
# allele funny: rs4848142 A G X X
# allele funny: rs2953080 G A X X
# allele funny: rs12479320 A G X X
# allele funny: rs10496584 A G X X
# allele funny: rs1919922 C T X X
# allele funny: rs896902 T G X X
# allele funny: rs10496605 G A X X
# allele funny: rs12623767 A G X X
# allele funny: rs1401565 G A X X
# allele funny: rs12619549 A G X X
# allele funny: rs1214118 G A X X
# allele funny: rs1881793 G A X X
# allele funny: rs7569367 C T X X
# allele funny: rs10445861 T C X X
# allele funny: rs4622728 T C X X
# allele funny: rs12998726 G A X X
# allele funny: rs10496654 T C X X
# allele funny: rs2118508 G A X X
# allele funny: rs4662637 T C X X
# allele funny: rs17049081 C A X X
# allele funny: rs2222901 A C X X
# allele funny: rs4850128 T C X X
# allele funny: rs13021106 C T X X
# allele funny: rs10185789 C T X X
# allele funny: rs12472079 C A X X
# allele funny: rs4953986 T C X X
# allele funny: rs1374744 C T X X
# allele funny: rs6754684 C A X X
# allele funny: rs2593712 C T X X
# allele funny: rs12988086 G T X X
# allele funny: rs13395693 T C X X
# allele funny: rs2289076 G A X X
# allele funny: rs901225 G A X X
# allele funny: rs7594310 G A X X
# allele funny: rs11689718 A G X X
# allele funny: rs7570971 C A X X
# allele funny: rs749873 C T X X
# allele funny: rs4954394 A G X X
# allele funny: rs778193 C T X X
# allele funny: rs12997811 A G X X
# allele funny: rs11682582 A G X X
# allele funny: rs13004492 A G X X
# allele funny: rs13002270 T C X X
# allele funny: rs10174953 A G X X
# allele funny: rs1837161 T C X X
# allele funny: rs6722928 G A X X
# allele funny: rs16843261 T C X X
# allele funny: rs10197964 G A X X
# allele funny: rs11894060 A C X X
# allele funny: rs1372256 G T X X
# allele funny: rs10153880 A G X X
# allele funny: rs6746848 G T X X
# allele funny: rs1835164 G A X X
# allele funny: rs6709738 C A X X
# allele funny: rs13006054 G A X X
# allele funny: rs1549709 C T X X
# allele funny: rs2091302 G A X X
# allele funny: rs1437349 C T X X
# allele funny: rs10928120 A C X X
# allele funny: rs974973 T C X X
# allele funny: rs16847202 A C X X
# allele funny: rs352985 G A X X
# allele funny: rs13382469 C T X X
# allele funny: rs16847914 C T X X
# allele funny: rs4662423 G T X X
# allele funny: rs2452477 G T X X
# allele funny: rs2381406 A G X X
# allele funny: rs7596229 A G X X
# allele funny: rs7580625 G A X X
# allele funny: rs10803495 G A X X
# allele funny: rs10469562 A G X X
# allele funny: rs12998885 T G X X
# allele funny: rs11888898 T C X X
# allele funny: rs13410341 T C X X
# allele funny: rs12691693 T C X X
# allele funny: rs1822881 A G X X
# allele funny: rs12615682 G A X X
# allele funny: rs6430095 G A X X
# allele funny: rs10496985 G A X X
# allele funny: rs10200377 T C X X
# allele funny: rs2381866 T C X X
# allele funny: rs11680349 T C X X
# allele funny: rs12479440 C T X X
# allele funny: rs16827299 A G X X
# allele funny: rs10199422 T C X X
# allele funny: rs10928364 A G X X
# allele funny: rs16827816 G T X X
# allele funny: rs10497026 C T X X
# allele funny: rs79793350 G A X X
# allele funny: rs2058686 C T X X
# allele funny: rs816889 A G X X
# allele funny: rs9789673 G T X X
# allele funny: rs10930331 G A X X
# allele funny: rs2271811 T C X X
# allele funny: rs72866484 G A X X
# allele funny: rs3768655 T G X X
# allele funny: rs1356732 T C X X
# allele funny: rs4664601 G A X X
# allele funny: rs6710313 A G X X
# allele funny: rs7599452 C T X X
# allele funny: rs7572009 G A X X
# allele funny: rs1439638 T C X X
# allele funny: rs1439630 A G X X
# allele funny: rs12466830 T C X X
# allele funny: rs17829861 G A X X
# allele funny: rs12479422 G A X X
# allele funny: rs1022386 C T X X
# allele funny: rs7579033 A G X X
# allele funny: rs10497137 T C X X
# allele funny: rs7590906 T C X X
# allele funny: rs16836088 G A X X
# allele funny: rs7592907 G A X X
# allele funny: rs16836440 G A X X
# allele funny: rs7576163 A C X X
# allele funny: rs16836561 T C X X
# allele funny: rs11895478 C T X X
# allele funny: rs985092 G A X X
# allele funny: rs11895298 A G X X
# allele funny: rs12471133 T C X X
# allele funny: rs10932860 A G X X
# allele funny: rs155597 T C X X
# allele funny: rs1357184 T C X X
# allele funny: rs7592105 G A X X
# allele funny: rs16843852 T G X X
# allele funny: rs2925755 A G X X
# allele funny: rs197273 A G X X
# allele funny: rs1267059 A C X X
# allele funny: rs4664044 T G X X
# allele funny: rs1399650 G A X X
# allele funny: rs2892792 A G X X
# allele funny: rs76204919 G A X X
# allele funny: rs2909448 C T X X
# allele funny: rs4420712 T G X X
# allele funny: rs5647 G A X X
# allele funny: rs985309 C T X X
# allele funny: rs8179642 G T X X
# allele funny: rs1870871 G A X X
# allele funny: rs2704358 A G X X
# allele funny: rs1531360 A G X X
# allele funny: rs2169219 A G X X
# allele funny: rs17810175 G A X X
# allele funny: rs1579872 A G X X
# allele funny: rs7574118 A C X X
# allele funny: rs268268 A G X X
# allele funny: rs1446468 T C X X
# allele funny: rs10167913 T C X X
# allele funny: rs510806 G A X X
# allele funny: rs7580761 G A X X
# allele funny: rs1717623 C T X X
# allele funny: rs4425091 C T X X
# allele funny: rs12328675 T C X X
# allele funny: rs6724963 C T X X
# allele funny: rs17829596 T C X X
# allele funny: rs2028364 A G X X
# allele funny: rs6718960 A G X X
# allele funny: rs4387807 C A X X
# allele funny: rs10427253 G T X X
# allele funny: rs16850912 A G X X
# allele funny: rs58268217 T G X X
# allele funny: rs11681250 C T X X
# allele funny: rs720087 G T X X
# allele funny: rs4426541 A G X X
# allele funny: rs10754969 C A X X
# allele funny: rs2091545 T C X X
# allele funny: rs11893208 A G X X
# allele funny: rs1511199 T G X X
# allele funny: rs2303877 C T X X
# allele funny: rs12479257 T C X X
# allele funny: rs12622054 G A X X
# allele funny: rs6740435 C T X X
# allele funny: rs10200961 A G X X
# allele funny: rs12479070 A G X X
# allele funny: rs1992928 G A X X
# allele funny: rs9646776 T C X X
# allele funny: rs4597482 C T X X
# allele funny: rs7561814 G A X X
# allele funny: rs13393173 G A X X
# allele funny: rs3821116 G T X X
# allele funny: rs10191750 A G X X
# allele funny: rs10169879 T C X X
# ...
# allele funny: rs1293713 G T X X
# allele funny: rs2424638 T C X X
# allele funny: rs6037206 C T X X
# allele funny: rs845796 T C X X
# allele funny: rs6120033 G A X X
# allele funny: rs1475769 G A X X
# allele funny: rs291671 G A X X
# allele funny: rs2065703 C T X X
# allele funny: rs6119407 A G X X
# allele funny: rs6088764 C A X X
# allele funny: rs224333 G A X X
# allele funny: rs6030712 G A X X
# allele funny: rs6018627 T C X X
# allele funny: rs6066892 C T X X
# allele funny: rs7353574 G A X X
# allele funny: rs1005611 A G X X
# allele funny: rs220541 G T X X
# allele funny: rs13040864 G A X X
# allele funny: rs926392 A G X X
# allele funny: rs2208139 T C X X
# allele funny: rs932384 G T X X
# allele funny: rs7274815 C T X X
# allele funny: rs2024907 G A X X
# allele funny: rs6101934 G A X X
# allele funny: rs6124298 G A X X
# allele funny: rs4142393 C T X X
# allele funny: rs4810329 T C X X
# allele funny: rs6102659 G T X X
# allele funny: rs6124419 G A X X
# allele funny: rs6102774 C T X X
# allele funny: rs11086837 A G X X
# allele funny: rs3092043 T C X X
# allele funny: rs3092292 G A X X
# allele funny: rs6030661 A G X X
# allele funny: rs4810379 A G X X
# allele funny: rs6017202 T G X X
# allele funny: rs6073269 A G X X
# allele funny: rs6130497 T G X X
# allele funny: rs1883680 G A X X
# allele funny: rs16988857 C T X X
# allele funny: rs6130569 G A X X
# allele funny: rs6094017 C T X X
# allele funny: rs2234197 G A X X
# allele funny: rs2664581 A C X X
# allele funny: rs2231616 C T X X
# allele funny: rs464318 G A X X
# allele funny: rs3827040 G A X X
# allele funny: rs3904166 G T X X
# allele funny: rs847101 A G X X
# allele funny: rs383551 G T X X
# allele funny: rs2151389 C T X X
# allele funny: rs6018477 A C X X
# allele funny: rs6094710 G A X X
# allele funny: rs6094723 A G X X
# allele funny: rs1361933 C T X X
# allele funny: rs976941 C T X X
# allele funny: rs852349 G A X X
# allele funny: rs852362 T G X X
# allele funny: rs6019266 C T X X
# allele funny: rs4810831 T C X X
# allele funny: rs506958 G A X X
# allele funny: rs6063413 A C X X
# allele funny: rs803194 G A X X
# allele funny: rs7266895 G A X X
# allele funny: rs4811068 C A X X
# allele funny: rs6126061 T C X X
# allele funny: rs6020739 T C X X
# allele funny: rs736214 A G X X
# allele funny: rs6067724 G A X X
# allele funny: rs6126238 C T X X
# allele funny: rs6096477 C A X X
# allele funny: rs6126313 C T X X
# allele funny: rs6067996 C A X X
# allele funny: rs13041126 T C X X
# allele funny: rs988675 T G X X
# allele funny: rs8117683 A G X X
# allele funny: rs12625311 T C X X
# allele funny: rs6126982 T G X X
# allele funny: rs210069 C T X X
# allele funny: rs16999165 A G X X
# allele funny: rs2256661 T C X X
# allele funny: rs459465 G A X X
# allele funny: rs4524177 G A X X
# allele funny: rs415502 A C X X
# allele funny: rs6024282 C A X X
# allele funny: rs6127565 C A X X
# allele funny: rs1474892 A C X X
# allele funny: rs6092184 T C X X
# allele funny: rs1047972 T C X X
# allele funny: rs77382732 G A X X
# allele funny: rs6069753 G A X X
# allele funny: rs3827108 T C X X
# allele funny: rs6092361 G A X X
# allele funny: rs6069891 G A X X
# allele funny: rs55745989 C T X X
# allele funny: rs13038306 G A X X
# allele funny: rs6025261 G A X X
# allele funny: rs1150429 C A X X
# allele funny: rs6025543 A G X X
# allele funny: rs205785 T C X X
# allele funny: rs618897 T G X X
# allele funny: rs486921 C T X X
# allele funny: rs12480449 C T X X
# allele funny: rs742927 G A X X
# allele funny: rs2426778 G A X X
# allele funny: rs919197 T C X X
# allele funny: rs151361 A G X X
# allele funny: rs197185 A G X X
# allele funny: rs6064780 G A X X
# allele funny: rs6015519 G A X X
# allele funny: rs6015534 G A X X
# allele funny: rs8184882 T C X X
# allele funny: rs6015741 A G X X
# allele funny: rs62198779 G A X X
# allele funny: rs2426930 G A X X
# allele funny: rs6065084 G A X X
# allele funny: rs4468878 T C X X
# allele funny: rs6061740 C A X X
# allele funny: rs868865 G A X X
# allele funny: rs7261632 C T X X
# allele funny: rs1891582 G A X X
# allele funny: rs944895 G A X X
# allele funny: rs11906462 C T X X
# allele funny: rs6011419 G A X X
# allele funny: rs11698778 G A X X
# allele funny: rs1000122 A G X X
# allele funny: rs6090265 C T X X
# allele funny: rs6122434 G A X X
# allele funny: rs2297441 G A X X
# allele funny: rs6011235 G A X X
# allele funny: rs4809256 C T X X
# allele funny: rs2822383 C T X X
# allele funny: rs2822426 A C X X
# allele funny: rs389493 T C X X
# allele funny: rs372992 A G X X
# allele funny: rs4816274 T G X X
# allele funny: rs2192161 G A X X
# allele funny: rs2822618 G A X X
# allele funny: rs2822754 G A X X
# allele funny: rs1292581 G T X X
# allele funny: rs2822924 C A X X
# allele funny: rs2823126 G A X X
# allele funny: rs9982931 A G X X
# allele funny: rs2823233 A C X X
# allele funny: rs6517467 T G X X
# allele funny: rs2823363 A C X X
# allele funny: rs9977930 C T X X
# allele funny: rs2823586 C T X X
# allele funny: rs2823611 G T X X
# allele funny: rs2823702 G A X X
# allele funny: rs2823743 T C X X
# allele funny: rs239019 A G X X
# allele funny: rs9983087 G A X X
# allele funny: rs2823877 G A X X
# allele funny: rs9975172 C T X X
# allele funny: rs2823962 A G X X
# allele funny: rs2823987 T C X X
# allele funny: rs2823992 A G X X
# allele funny: rs979045 C T X X
# allele funny: rs1014604 G A X X
# allele funny: rs2205320 G T X X
# allele funny: rs765143 C T X X
# allele funny: rs2824226 A G X X
# allele funny: rs2824268 G A X X
# allele funny: rs2824271 G A X X
# allele funny: rs4320015 G A X X
# allele funny: rs2824332 C T X X
# allele funny: rs1389995 A C X X
# allele funny: rs2824455 C T X X
# allele funny: rs12483463 A G X X
# allele funny: rs158026 G A X X
# allele funny: rs1491781 T C X X
# allele funny: rs2183557 C T X X
# allele funny: rs10084615 C T X X
# allele funny: rs8130250 G A X X
# allele funny: rs989891 C T X X
# allele funny: rs17699052 A G X X
# allele funny: rs2824821 A C X X
# allele funny: rs8129824 G A X X
# allele funny: rs8131046 T C X X
# allele funny: rs9981885 A C X X
# allele funny: rs2825572 A G X X
# allele funny: rs1489734 G A X X
# allele funny: rs2825717 A G X X
# allele funny: rs2825809 G T X X
# allele funny: rs17003317 A G X X
# allele funny: rs2825875 A G X X
# allele funny: rs73317713 G T X X
# allele funny: rs2825978 C T X X
# allele funny: rs2826213 C T X X
# allele funny: rs990241 A G X X
# allele funny: rs2826324 C T X X
# allele funny: rs2826334 T G X X
# allele funny: rs2826339 A G X X
# allele funny: rs2826348 C T X X
# allele funny: rs70431 G A X X
# allele funny: rs2826437 T G X X
# allele funny: rs1384315 G A X X
# allele funny: rs1009164 C T X X
# allele funny: rs9980583 A G X X
# allele funny: rs2826672 C T X X
# allele funny: rs12483298 G A X X
# allele funny: rs2826710 C T X X
# allele funny: rs2826721 A G X X
# allele funny: rs2897831 T C X X
# allele funny: rs2826844 G A X X
# allele funny: rs1460089 G T X X
# allele funny: rs975306 C A X X
# allele funny: rs1735964 A G X X
# allele funny: rs2826983 G A X X
# allele funny: rs2211979 A C X X
# allele funny: rs2827143 G A X X
# allele funny: rs111892515 C T X X
# allele funny: rs13050520 T C X X
# allele funny: rs1918388 A C X X
# allele funny: rs2827728 A C X X
# allele funny: rs244137 T C X X
# allele funny: rs2827806 A G X X
# allele funny: rs12482466 T C X X
# allele funny: rs768176 A G X X
# allele funny: rs2828154 G A X X
# allele funny: rs2828242 C T X X
# allele funny: rs2212575 A G X X
# allele funny: rs7278243 G A X X
# allele funny: rs11910832 A C X X
# allele funny: rs2828657 T C X X
# allele funny: rs7276625 T G X X
# allele funny: rs16999508 G T X X
# allele funny: rs12627150 T G X X
# allele funny: rs727680 T C X X
# allele funny: rs12053689 C T X X
# allele funny: rs2829237 A G X X
# allele funny: rs2829247 C T X X
# allele funny: rs2829297 G A X X
# allele funny: rs11701407 A C X X
# allele funny: rs2829432 A G X X
# allele funny: rs2829456 T C X X
# allele funny: rs765282 T C X X
# allele funny: rs4817016 T C X X
# allele funny: rs2829950 G T X X
# allele funny: rs1041731 A G X X
# allele funny: rs9975851 C T X X
# allele funny: rs2830201 T C X X
# allele funny: rs222920 A C X X
# allele funny: rs4172 C A X X
# allele funny: rs9976844 C T X X
# allele funny: rs465401 A G X X
# allele funny: rs406069 T C X X
# allele funny: rs8132630 C A X X
# allele funny: rs2831140 A G X X
# allele funny: rs3844464 A C X X
# allele funny: rs243660 G A X X
# allele funny: rs243700 A G X X
# allele funny: rs2831450 A G X X
# allele funny: rs2831463 C T X X
# allele funny: rs2831484 G A X X
# allele funny: rs10482989 T C X X
# allele funny: rs8131527 C T X X
# allele funny: rs2243552 T G X X
# allele funny: rs3787662 C A X X
# allele funny: rs2832238 G T X X
# allele funny: rs9982288 C T X X
# allele funny: rs17744121 A G X X
# allele funny: rs914136 T C X X
# allele funny: rs2032305 G A X X
# allele funny: rs7276462 C T X X
# allele funny: rs2832660 C A X X
# allele funny: rs2226821 T C X X
# allele funny: rs2833114 G A X X
# allele funny: rs2833159 A G X X
# allele funny: rs2243936 G A X X
# allele funny: rs475142 C T X X
# allele funny: rs2284543 G A X X
# allele funny: rs2833446 T G X X
# allele funny: rs2833458 A G X X
# allele funny: rs204732 G A X X
# allele funny: rs11910494 A G X X
# allele funny: rs11702795 G T X X
# allele funny: rs9975800 A G X X
# allele funny: rs2833841 G A X X
# allele funny: rs2834009 T C X X
# allele funny: rs2834046 G A X X
# allele funny: rs8131457 T C X X
# allele funny: rs2256797 T C X X
# allele funny: rs2834772 C T X X
# allele funny: rs8129353 A G X X
# allele funny: rs8133843 G A X X
# allele funny: rs2834932 T C X X
# allele funny: rs2834940 G A X X
# allele funny: rs1627997 C T X X
# allele funny: rs4817775 A C X X
# allele funny: rs219781 G T X X
# allele funny: rs219780 C T X X
# allele funny: rs1065758 G A X X
# allele funny: rs2836338 A C X X
# allele funny: rs2836524 G A X X
# allele funny: rs460049 T C X X
# allele funny: rs459094 G T X X
# allele funny: rs73209393 T G X X
# allele funny: rs2836843 A G X X
# allele funny: rs2244352 T G X X
# allele funny: rs2837035 A G X X
# allele funny: rs7281425 A G X X
# allele funny: rs512384 C T X X
# allele funny: rs2837113 G A X X
# allele funny: rs7283208 G A X X
# allele funny: rs368269 C T X X
# allele funny: rs11701316 T C X X
# allele funny: rs1734936 A G X X
# allele funny: rs2837466 T C X X
# allele funny: rs11909875 T C X X
# allele funny: rs8133535 T C X X
# allele funny: rs1571717 T C X X
# allele funny: rs461980 C T X X
# allele funny: rs460699 C T X X
# allele funny: rs1888514 G A X X
# allele funny: rs2838075 T C X X
# allele funny: rs2838095 G T X X
# allele funny: rs12626385 G A X X
# allele funny: rs9982608 G A X X
# allele funny: rs177933 A G X X
# allele funny: rs220215 T C X X
# allele funny: rs11701143 T C X X
# allele funny: rs10595 G A X X
# allele funny: rs170918 G A X X
# allele funny: rs234709 C T X X
# allele funny: rs9974326 A G X X
# allele funny: rs7276207 G A X X
# allele funny: rs7282490 G A X X
# allele funny: rs2070565 T C X X
# allele funny: rs8130070 A G X X
# allele funny: rs1556314 T G X X
# allele funny: rs2329817 A G X X
# allele funny: rs460380 C A X X
# allele funny: rs170962 C T X X
# allele funny: rs417580 C T X X
# allele funny: rs760458 C A X X
# allele funny: rs9977697 T G X X
# allele funny: rs2838912 G A X X
# allele funny: rs2183590 A G X X
# allele funny: rs2838942 A G X X
# allele funny: rs7867 G A X X
# allele funny: rs4818789 G T X X
# allele funny: rs944422 T C X X
# allele funny: rs1053312 G A X X
# allele funny: rs2839112 T C X X
# allele funny: rs2072466 C T X X
# allele funny: rs2192431 T G X X
# allele funny: rs165778 T C X X
# allele funny: rs79822985 A G X X
# allele funny: rs5748955 A G X X
# allele funny: rs737967 C T X X
# allele funny: rs5994256 T C X X
# allele funny: rs5992044 G A X X
# allele funny: rs174330 T C X X
# allele funny: rs412830 T C X X
# allele funny: rs181399 C T X X
# allele funny: rs7675 C T X X
# allele funny: rs2277831 A G X X
# allele funny: rs712965 G A X X
# allele funny: rs5993715 G T X X
# allele funny: rs9606160 A G X X
# allele funny: rs7289747 A C X X
# allele funny: rs2239393 A G X X
# allele funny: rs1153427 C T X X
# allele funny: rs8748 A G X X
# allele funny: rs17818796 A G X X
# allele funny: rs756875 G A X X
# allele funny: rs9625334 C A X X
# allele funny: rs408718 C T X X
# allele funny: rs2298428 C T X X
# allele funny: rs9610417 C T X X
# allele funny: rs8136867 G A X X
# allele funny: rs5750496 T C X X
# allele funny: rs2213953 C T X X
# allele funny: rs9612334 A G X X
# allele funny: rs738781 G A X X
# allele funny: rs4822423 C T X X
# allele funny: rs2236620 C T X X
# allele funny: rs5760180 T G X X
# allele funny: rs5751940 T C X X
# allele funny: rs131476 C T X X
# allele funny: rs5751997 T C X X
# allele funny: rs139662 A G X X
# allele funny: rs139763 T C X X
# allele funny: rs5760942 A G X X
# allele funny: rs5761313 G T X X
# allele funny: rs134740 A G X X
# allele funny: rs16982905 G T X X
# allele funny: rs11704127 G A X X
# allele funny: rs9625200 C T X X
# allele funny: rs960613 G A X X
# allele funny: rs12160358 A G X X
# allele funny: rs4820773 G A X X
# allele funny: rs1569950 A G X X
# allele funny: rs695318 G A X X
# allele funny: rs738722 T C X X
# allele funny: rs2412970 A G X X
# allele funny: rs2413001 C T X X
# allele funny: rs5998115 T C X X
# allele funny: rs5753991 G A X X
# allele funny: rs9609537 T C X X
# allele funny: rs117775223 T C X X
# allele funny: rs5998545 A C X X
# allele funny: rs2051568 G A X X
# allele funny: rs5998590 A G X X
# allele funny: rs5754289 C T X X
# allele funny: rs135029 A G X X
# allele funny: rs2142550 T C X X
# allele funny: rs7287710 T C X X
# allele funny: rs240073 A G X X
# allele funny: rs5754734 T G X X
# allele funny: rs243001 A C X X
# allele funny: rs5994882 A C X X
# allele funny: rs5755038 G T X X
# allele funny: rs5755093 T G X X
# allele funny: rs5755486 G A X X
# allele funny: rs5999797 G A X X
# allele funny: rs5995235 C T X X
# allele funny: rs5756214 C T X X
# allele funny: rs2075936 A G X X
# allele funny: rs229535 G T X X
# allele funny: rs5995416 T C X X
# allele funny: rs8135665 C T X X
# allele funny: rs6001064 C T X X
# allele funny: rs5757277 G A X X
# allele funny: rs5757387 G A X X
# allele funny: rs12159200 A C X X
# allele funny: rs5996094 T C X X
# allele funny: rs9611766 G A X X
# allele funny: rs733278 A C X X
# allele funny: rs137085 T C X X
# allele funny: rs130328 G A X X
# allele funny: rs3788594 A C X X
# allele funny: rs62231618 C T X X
# allele funny: rs5759256 T C X X
# allele funny: rs7290575 G A X X
# allele funny: rs5764236 A G X X
# allele funny: rs9968041 A C X X
# allele funny: rs713964 T C X X
# allele funny: rs1883350 T C X X
# allele funny: rs2267601 G A X X
# allele funny: rs738482 T C X X
# allele funny: rs11703924 C T X X
# allele funny: rs7511423 C T X X
# allele funny: rs9614891 T G X X
# allele funny: rs5765896 T C X X
# allele funny: rs5764925 G A X X
# allele funny: rs73173644 C T X X
# allele funny: rs5766546 G A X X
# allele funny: rs2294196 C T X X
# allele funny: rs5765370 G A X X
# allele funny: rs713896 A G X X
# allele funny: rs885792 T C X X
# allele funny: rs974226 T C X X
# allele funny: rs766168 C T X X
# allele funny: rs131853 T C X X
# allele funny: rs10460765 T C X X
# allele funny: rs738733 A C X X
# allele funny: rs5768202 T C X X
# allele funny: rs131137 A C X X
# allele funny: rs9615811 A C X X
# allele funny: rs4823756 C T X X
# allele funny: rs4823776 A G X X
# allele funny: rs10460766 G A X X
# allele funny: rs80517 T C X X
# allele funny: rs8142256 T C X X
# allele funny: rs9617458 C T X X
# allele funny: rs28497237 T C X X
# allele funny: rs5769415 G A X X
# allele funny: rs75167430 C T X X
# allele funny: rs1547426 C T X X
# allele funny: rs11705420 G A X X
# allele funny: rs877161 G A X X
# allele funny: rs713997 A G X X
# allele funny: rs136771 A G X X
# allele funny: rs5770418 C T X X
# allele funny: rs58422561 G A X X
# allele funny: rs3922872 T C X X
# allele funny: rs137862 C A X X
# allele funny: rs11101958 C T X X
# allele funny: rs138224 G A X X
# allele funny: rs7510868 G A X X
# allele funny: rs131788 T C X X
# allele funny: rs73172277 C T X X
# read 1073741824 bytes
# read 2147483648 bytes
# read 3221225472 bytes
# read 4294967296 bytes
# read 5052887274 bytes
# packed geno read OK
# end of inpack
# numsnps input: 1233013 602059
# eigenstrat output
# numsnps output: 127120  numindivs: 16390
#
#
# Histogram of checkmatch return codes
# kode:   -2      3  A/T or C/G and strandcheck
# kode:    0  12018  Allele mismatch
# kode:    1  60670  SNP OK (no flip)
# kode:    2  66450  SNP OK (flip)
# total:         139141
#
# ##end of mergeit:     1172.070 seconds cpu      952.517 Mbytes in use
#
# Standard Error:

# %%
# !ls
# Out:
# convertf		getresult			 qpff3base
# convertf_param.par	grabpars			 qpfmv
# dataset			jackdiff			 qpfstats
# dof4			kimf				 qpGraph
# dof4a			LICENSE				 qpmix
# dowtjack		mergeit				 qpreroot
# expfit.sh		merge_param.par			 qpWave
# gcount			mkpretty			 rexpfit.r
# Genome_eigenstrat.geno	numlines			 rolloff
# Genome_eigenstrat.ind	plink				 rolloffp
# Genome_eigenstrat.snp	plink_linux_x86_64_20231211.zip  simpjack2
# Genome_merged.bed	prettify			 toy.map
# Genome_merged.bim	qp3Pop				 toy.ped
# Genome_merged.fam	qp4diff				 v54.1.p1_1240K_public.tar
# Genome_merged_hh.bed	qpAdm				 wtjack.pl
# Genome_merged_hh.bim	qpBound				 xtractcol
# Genome_merged_hh.fam	qpDpart				 xtractcolv
# Genome_merged_hh.log	qpdslow				 Yusup_merged_with_1240K.geno
# Genome_merged.log	qpDstat				 Yusup_merged_with_1240K.ind
# genome.txt		qpF4ratio			 Yusup_merged_with_1240K.snp

# %%
# Define the path to the file
file_path = '/content/AdmixTools-master/bin/Yusup_merged_with_1240K.ind'

# Function to read the last few lines of a file
def read_last_lines(file_path, num_lines=10):
    try:
        with open(file_path, 'r') as file:
            # Read all lines from the file
            lines = file.readlines()
            # Print the last few lines
            for line in lines[-num_lines:]:
                print(line.strip())
    except Exception as e:
        print(f"An error occurred: {e}")

# Call the function to read the last few lines
read_last_lines(file_path, num_lines=10)
# Out:
# I14343_v54.1_addback M Armenia_EBA_KuraAraxes
# I8959_v54.1_addback M   Iraq_PPN
# I17633_v54.1_addback M Albania_BA_IA_oCroat_1d.rel.I16256
# I18114_v54.1_addback M Romania_C_Bodrogkeresztur_brother.I15617.brother.I7135
# I19456_v54.1_addback M Bulgaria_EBA
# S1944.E1.L3_v54.1_addback F Iran_GanjDareh_N
# S1951.E1.L3_v54.1_addback F Iran_GanjDareh_N
# S7241.E1.L1_v54.1_addback M Vietnam_N_all
# I1877_v54.1_addback M Hungary_EN_Starcevo_2_all
# Yusup:R F        ???

# %%
# Define the path to the file
file_path = '/content/AdmixTools-master/bin/Yusup_merged_with_1240K.ind'

# Function to modify the last line of the file
def modify_last_line(file_path, new_line):
    try:
        # Read all lines from the file
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Modify the last line
        if lines:
            lines[-1] = new_line + '\n'

        # Write the modified lines back to the file
        with open(file_path, 'w') as file:
            file.writelines(lines)
        print("Last line modified successfully.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Define the new last line
new_last_line = "Rozimemet Uyghur Yusup"

# Call the function to modify the last line
modify_last_line(file_path, new_last_line)
# Out:
# Last line modified successfully.

# %%
# Define the path to the file
file_path = '/content/AdmixTools-master/bin/Yusup_merged_with_1240K.ind'

# Function to read the last few lines of a file
def read_last_lines(file_path, num_lines=10):
    try:
        with open(file_path, 'r') as file:
            # Read all lines from the file
            lines = file.readlines()
            # Print the last few lines
            for line in lines[-num_lines:]:
                print(line.strip())
    except Exception as e:
        print(f"An error occurred: {e}")

# Call the function to read the last few lines
read_last_lines(file_path, num_lines=10)
# Out:
# I14343_v54.1_addback M Armenia_EBA_KuraAraxes
# I8959_v54.1_addback M   Iraq_PPN
# I17633_v54.1_addback M Albania_BA_IA_oCroat_1d.rel.I16256
# I18114_v54.1_addback M Romania_C_Bodrogkeresztur_brother.I15617.brother.I7135
# I19456_v54.1_addback M Bulgaria_EBA
# S1944.E1.L3_v54.1_addback F Iran_GanjDareh_N
# S1951.E1.L3_v54.1_addback F Iran_GanjDareh_N
# S7241.E1.L1_v54.1_addback M Vietnam_N_all
# I1877_v54.1_addback M Hungary_EN_Starcevo_2_all
# Rozimemet Uyghur Yusup

# %%
import os

# Define the paths for the new folders
bin_directory = '/content/AdmixTools-master/bin'
fstat_genome_path = os.path.join(bin_directory, 'fstat_genome')
fstat_ancestry_path = os.path.join(bin_directory, 'fstat_ancestry')

# Create the new folders
os.makedirs(fstat_genome_path, exist_ok=True)
os.makedirs(fstat_ancestry_path, exist_ok=True)

print("Folders 'fstat_genome' and 'fstat_ancestry' created successfully.")
# Out:
# Folders 'fstat_genome' and 'fstat_ancestry' created successfully.

# %%
# !ls
# Out:
# convertf		genome.txt			 qpff3base
# convertf_param.par	getresult			 qpfmv
# dataset			grabpars			 qpfstats
# dof4			jackdiff			 qpGraph
# dof4a			kimf				 qpmix
# dowtjack		LICENSE				 qpreroot
# expfit.sh		mergeit				 qpWave
# fstat_ancestry		merge_param.par			 rexpfit.r
# fstat_genome		mkpretty			 rolloff
# gcount			numlines			 rolloffp
# Genome_eigenstrat.geno	plink				 simpjack2
# Genome_eigenstrat.ind	plink_linux_x86_64_20231211.zip  toy.map
# Genome_eigenstrat.snp	prettify			 toy.ped
# Genome_merged.bed	qp3Pop				 v54.1.p1_1240K_public.tar
# Genome_merged.bim	qp4diff				 wtjack.pl
# Genome_merged.fam	qpAdm				 xtractcol
# Genome_merged_hh.bed	qpBound				 xtractcolv
# Genome_merged_hh.bim	qpDpart				 Yusup_merged_with_1240K.geno
# Genome_merged_hh.fam	qpdslow				 Yusup_merged_with_1240K.ind
# Genome_merged_hh.log	qpDstat				 Yusup_merged_with_1240K.snp
# Genome_merged.log	qpF4ratio

# %%
cd fstat_genome/
# Out:
# /content/AdmixTools-master/bin/fstat_genome

# %%
# Define the content for the parqpfstat.txt file
content = """DIR:                 /content/AdmixTools-master/bin
S1:                  10Oct21
S1X:                 10Oct21
indivname:           /content/AdmixTools-master/bin/Yusup_merged_with_1240K.ind
snpname:             /content/AdmixTools-master/bin/Yusup_merged_with_1240K.snp
genotypename:        /content/AdmixTools-master/bin/Yusup_merged_with_1240K.geno
poplistname:         /content/AdmixTools-master/bin/fstat_genome/lista.txt
fstatsoutname:       /content/AdmixTools-master/bin/fstat_genome/fstatsa.txt
allsnps:             YES
inbreed:             NO
scale:               NO
"""

# Define the path for the parqpfstat.txt file
file_path = '/content/AdmixTools-master/bin/fstat_genome/parqpfstat.txt'

# Write the content to the parqpfstat.txt file
with open(file_path, 'w') as file:
    file.write(content)

print(f"'parqpfstat.txt' created successfully at {file_path}.")
# Out:
# 'parqpfstat.txt' created successfully at /content/AdmixTools-master/bin/fstat_genome/parqpfstat.txt.

# %%
# Define the content for lista.txt
content = """
Yusup
Mbuti.DG
Irula.DG
Turkey_N
Laos_LN_BA.SG
China_Tianyuan
Ami.DG
Karitiana.DG
Iran_GanjDareh_N
Iran_C_SehGabi
Iran_ShahrISokhta_BA1
Iran_ShahrISokhta_BA2
Turkmenistan_Gonur_BA_1
Dai.DG
Russia_Ust_Ishim_HG.DG
Chukchi.DG
Saami.DG
Georgia_Kotias.SG
Russia_Kostenki14.SG
Russia_Tyumen_HG
Russia_MLBA_Sintashta
Russia_DevilsCave_N.SG
Luxembourg_Loschbour.DG
Czech_BellBeaker
Kazakhstan_Central_Saka.SG
Portugal_MN.SG
Kazakhstan_Andronovo.SG
"""

# Define the path for the lista.txt file
file_path = '/content/AdmixTools-master/bin/fstat_genome/lista.txt'

# Write the content to the lista.txt file
with open(file_path, 'w') as file:
    file.write(content)

print(f"'lista.txt' created successfully at {file_path}.")
# Out:
# 'lista.txt' created successfully at /content/AdmixTools-master/bin/fstat_genome/lista.txt.

# %%
# Define the file paths
lista_file = '/content/AdmixTools-master/bin/fstat_genome/lista.txt'
parqpfstat_file = '/content/AdmixTools-master/bin/fstat_genome/parqpfstat.txt'

# Function to read a few lines from a file
def read_few_lines(file_path, num_lines=11):
    try:
        with open(file_path, 'r') as file:
            lines = [next(file).strip() for _ in range(num_lines)]
        return lines
    except FileNotFoundError:
        return []

# Read a few lines from lista.txt
print(f"Reading first 11 lines from {lista_file}:")
lines_lista = read_few_lines(lista_file)
for line in lines_lista:
    print(line)
print()

# Read a few lines from parqpfstat.txt
print(f"Reading first 11 lines from {parqpfstat_file}:")
lines_parqpfstat = read_few_lines(parqpfstat_file)
for line in lines_parqpfstat:
    print(line)
# Out:
# Reading first 11 lines from /content/AdmixTools-master/bin/fstat_genome/lista.txt:
#
# Yusup
# Mbuti.DG
# Irula.DG
# Turkey_N
# Laos_LN_BA.SG
# China_Tianyuan
# Ami.DG
# Karitiana.DG
# Iran_GanjDareh_N
# Iran_C_SehGabi
#
# Reading first 11 lines from /content/AdmixTools-master/bin/fstat_genome/parqpfstat.txt:
# DIR:                 /content/AdmixTools-master/bin
# S1:                  10Oct21
# S1X:                 10Oct21
# indivname:           /content/AdmixTools-master/bin/Yusup_merged_with_1240K.ind
# snpname:             /content/AdmixTools-master/bin/Yusup_merged_with_1240K.snp
# genotypename:        /content/AdmixTools-master/bin/Yusup_merged_with_1240K.geno
# poplistname:         /content/AdmixTools-master/bin/fstat_genome/lista.txt
# fstatsoutname:       /content/AdmixTools-master/bin/fstat_genome/fstatsa.txt
# allsnps:             YES
# inbreed:             NO
# scale:               NO

# %%
import shutil

# Define paths for source and destination files
source_parqpfstat = '/content/AdmixTools-master/bin/fstat_genome/parqpfstat.txt'
source_lista = '/content/AdmixTools-master/bin/fstat_genome/lista.txt'

dest_parqpfstat = '/content/AdmixTools-master/bin/fstat_ancestry/parqpfstat.txt'
dest_lista = '/content/AdmixTools-master/bin/fstat_ancestry/lista.txt'

# Copy parqpfstat.txt
shutil.copyfile(source_parqpfstat, dest_parqpfstat)
print(f"Copied {source_parqpfstat} to {dest_parqpfstat}")

# Copy lista.txt
shutil.copyfile(source_lista, dest_lista)
print(f"Copied {source_lista} to {dest_lista}")
# Out:
# Copied /content/AdmixTools-master/bin/fstat_genome/parqpfstat.txt to /content/AdmixTools-master/bin/fstat_ancestry/parqpfstat.txt
# Copied /content/AdmixTools-master/bin/fstat_genome/lista.txt to /content/AdmixTools-master/bin/fstat_ancestry/lista.txt

# %%
# !./qpfstats -p fstat_genome/parqpfstat.txt > fstat_genome/qpfstatlog.txt
# !./qpfstats -p fstat_ancestry/parqpfstat.txt > fstat_ancestry/qpfstatlog.txt
# Out:
# ^C
# ^C

# %%
# Define the file paths
lista_file = '/content/AdmixTools-master/bin/fstat_genome/qpfstatlog.txt'
parqpfstat_file = '/content/AdmixTools-master/bin/fstat_genome/fstatsa.txt'

# Function to read a few lines from a file
def read_few_lines(file_path, num_lines=50):
    try:
        with open(file_path, 'r') as file:
            lines = [next(file).strip() for _ in range(num_lines)]
        return lines
    except FileNotFoundError:
        return []

# Read a few lines from lista.txt
print(f"Reading first 50 lines from {lista_file}:")
lines_lista = read_few_lines(lista_file)
for line in lines_lista:
    print(line)
print()

# Read a few lines from parqpfstat.txt
print(f"Reading first 50 lines from {parqpfstat_file}:")
lines_parqpfstat = read_few_lines(parqpfstat_file)
for line in lines_parqpfstat:
    print(line)
# Out:
# Reading first 50 lines from /content/AdmixTools-master/bin/fstat_genome/qpfstatlog.txt:
# parameter file: fstat_genome/parqpfstat.txt
# ### THE INPUT PARAMETERS
# ##PARAMETER NAME: VALUE
# DIR: /content/AdmixTools-master/bin
# S1: 10Oct21
# S1X: 10Oct21
# indivname: /content/AdmixTools-master/bin/Yusup_merged_with_1240K.ind
# snpname: /content/AdmixTools-master/bin/Yusup_merged_with_1240K.snp
# genotypename: /content/AdmixTools-master/bin/Yusup_merged_with_1240K.geno
# poplistname: /content/AdmixTools-master/bin/fstat_genome/lista.txt
# fstatsoutname: /content/AdmixTools-master/bin/fstat_genome/fstatsa.txt
# allsnps: YES
# inbreed: NO
# scale: NO
# ## qpfstats version: 540
# inbreed set NO
# allsnps set
# np: 27 n: 61776 nbasis: 351 coefsize: 21683376
# 0 Yusup
# 1 Mbuti.DG
# 2 Irula.DG
# 3 Turkey_N
# 4 Laos_LN_BA.SG
# 5 China_Tianyuan
# 6 Ami.DG
# 7 Karitiana.DG
# 8 Iran_GanjDareh_N
# 9 Iran_C_SehGabi
# 10 Iran_ShahrISokhta_BA1
# 11 Iran_ShahrISokhta_BA2
# 12 Turkmenistan_Gonur_BA_1
# 13 Dai.DG
# 14 Russia_Ust_Ishim_HG.DG
# 15 Chukchi.DG
# 16 Saami.DG
# 17 Georgia_Kotias.SG
# 18 Russia_Kostenki14.SG
# 19 Russia_Tyumen_HG
# 20 Russia_MLBA_Sintashta
# 21 Russia_DevilsCave_N.SG
# 22 Luxembourg_Loschbour.DG
# 23 Czech_BellBeaker
# 24 Kazakhstan_Central_Saka.SG
# 25 Portugal_MN.SG
# 26 Kazakhstan_Andronovo.SG
# outpop: NULL
# before setwt numsnps: 127120
# setwt numsnps: 126363
# number of blocks for moving block jackknife: 710
# snps: 126363  indivs: 250
#
# Reading first 50 lines from /content/AdmixTools-master/bin/fstat_genome/fstatsa.txt:
# ##fbasis.  basepop: Yusup ::  f3*1000 covar*1000000
# Mbuti.DG        Mbuti.DG     70.774788
# Mbuti.DG        Irula.DG      2.907756
# Mbuti.DG        Turkey_N      2.325529
# Mbuti.DG   Laos_LN_BA.SG      0.555749
# Mbuti.DG  China_Tianyuan      5.851766
# Mbuti.DG          Ami.DG     -1.841830
# Mbuti.DG    Karitiana.DG     -0.902632
# Mbuti.DG Iran_GanjDareh_N      3.979722
# Mbuti.DG  Iran_C_SehGabi      3.089666
# Mbuti.DG Iran_ShahrISokhta_BA1      3.016785
# Mbuti.DG Iran_ShahrISokhta_BA2      3.078171
# Mbuti.DG Turkmenistan_Gonur_BA_1      2.382202
# Mbuti.DG          Dai.DG     -0.690754
# Mbuti.DG Russia_Ust_Ishim_HG.DG      8.781918
# Mbuti.DG      Chukchi.DG     -0.816480
# Mbuti.DG        Saami.DG     -1.185787
# Mbuti.DG Georgia_Kotias.SG      3.183254
# Mbuti.DG Russia_Kostenki14.SG      4.457569
# Mbuti.DG Russia_Tyumen_HG     -0.583743
# Mbuti.DG Russia_MLBA_Sintashta      0.418446
# Mbuti.DG Russia_DevilsCave_N.SG     -3.064810
# Mbuti.DG Luxembourg_Loschbour.DG      1.304199
# Mbuti.DG Czech_BellBeaker      1.189379
# Mbuti.DG Kazakhstan_Central_Saka.SG     -0.545378
# Mbuti.DG  Portugal_MN.SG      1.766626
# Mbuti.DG Kazakhstan_Andronovo.SG      2.915980
# Irula.DG        Irula.DG      9.846492
# Irula.DG        Turkey_N     -1.253063
# Irula.DG   Laos_LN_BA.SG      1.065650
# Irula.DG  China_Tianyuan      2.652591
# Irula.DG          Ami.DG     -1.028393
# Irula.DG    Karitiana.DG     -1.199409
# Irula.DG Iran_GanjDareh_N      0.943005
# Irula.DG  Iran_C_SehGabi     -0.102993
# Irula.DG Iran_ShahrISokhta_BA1      1.895825
# Irula.DG Iran_ShahrISokhta_BA2      4.273237
# Irula.DG Turkmenistan_Gonur_BA_1      1.129385
# Irula.DG          Dai.DG     -1.219697
# Irula.DG Russia_Ust_Ishim_HG.DG      1.830555
# Irula.DG      Chukchi.DG     -1.510785
# Irula.DG        Saami.DG     -2.153857
# Irula.DG Georgia_Kotias.SG     -0.294460
# Irula.DG Russia_Kostenki14.SG      0.180676
# Irula.DG Russia_Tyumen_HG     -1.133298
# Irula.DG Russia_MLBA_Sintashta     -1.604352
# Irula.DG Russia_DevilsCave_N.SG     -3.434707
# Irula.DG Luxembourg_Loschbour.DG     -1.261204
# Irula.DG Czech_BellBeaker     -1.056699
# Irula.DG Kazakhstan_Central_Saka.SG     -1.454226
